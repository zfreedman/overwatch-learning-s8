# %% [markdown]
# # Overwatch Battletag Scraper

# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup as bs
import urllib2
from pathlib2 import Path
import codecs
import time
import threading

# %% [markdown]
# ### Hero Files

# %%
hero_dir = "../data/hero/"
hero_list = ["ana",
             "bastion",
             "d.va", "doomfist",
             "genji",
             "hanzo",
             "junkrat",
             "lucio",
             "mccree", "mei", "mercy", "moira",
             "orisa",
             "pharah",
             "reaper", "reinhardt", "roadhog",
             "soldier76", "sombra", "symmetra",
             "torbjorn", "tracer",
             "widowmaker", "winston",
             "zarya", "zenyatta"]
hero_dict = {}
for hero in hero_list:
    hero_dict[hero] = 1

# %% [markdown]
# ### Hero Helpers

# %%
def add_key(tds, info):
    """
    Given a td list of 2, adds the KVP tds[0].getText(), tds[1].getText() to the info map.
    This function also preprocesses times, percentages, and numbers to remove (:), (%), and (,)
    characters.
    """
    key = td_to_feat(tds[0].getText())
    val = tds[1].getText()
    #Process times with : to seconds
    is_time = False
    if ":" in val:
        is_time = True
        val_list = val.split(":")
        #Multipliers list to convert to seconds
        #days, hours, minutes, seconds
        mults = [86400, 3600, 60, 1]
        seconds = 0
        length = len(val_list)
        for i in range(length):
            seconds += int(val_list[length - i - 1]) * mults[length - i - 1]
        val = seconds
        key += "_seconds"
    #Time played
    elif "hours" in val.lower():
        val = int(val.lower().replace(" hours", "").replace(",", ""))
        key += "_hours"
    #Process percentages to decimal
    elif "%" in val:
        val = int(val.replace("%", "")) * 1.0 / 100
    #Process numbers without ,'s
    else:
        val = int("".join(val.split(",")))
    #Add kvp
    info[key] = val


#Multipliers list to convert to seconds
#days, hours, minutes, seconds
mults = [86400, 3600, 60, 1]
mult_length = len(mults)
def add_keys_from_tbody(tbody, info):
    """
    Given a td list of 2, adds the KVP tds[0].getText(), tds[1].getText() to the info map.
    This function also preprocesses times, percentages, and numbers to remove (:), (%), and (,)
    characters.
    """
    trows = tbody.find_all("tr")
    for i in range(len(trows)):
        tds = trows[i].find_all("td")
        key = td_to_feat(tds[0].getText())
        val = tds[1].getText().lower()
        #print(key, val)
        #Process times with : to seconds
        is_time = False
        if ":" in val:
            is_time = True
            val_list = val.split(":")
            #Multipliers list to convert to seconds
            #days, hours, minutes, seconds
            seconds = 0
            val_length = len(val_list)
            for i in range(val_length):
                seconds += int(val_list[val_length - i - 1]) * mults[mult_length - i - 1]
            val = seconds
            key += "_seconds"
        #Time played hours
        elif "hours" in val or "hour" in val:
            val = int(val.replace(" hour","").replace("s","").replace(",","")) * 60**2
            key += "_seconds"
        #Time played minutes
        elif "minutes" in val or "minute" in val:
            #int(float("2.4")) works whereas int("2.4") doesn't
            val = int(float(val.replace(" minute","").replace("s","").replace(",",""))) * 60
            key += "_seconds"
        #Time played seconds
        elif "seconds" in val or "second" in val:
             #int(float("2.4")) works whereas int("2.4") doesn't
            val = int(float(val.replace(" second","").replace("s","").replace(",","")))
            key += "_seconds"
        #Process percentages to decimal
        elif "%" in val:
            val = int(val.replace("%", "")) * 1.0 / 100
        #Process decimals to floats
        elif "." in val:
            val = float(val.replace(",", ""))
        #Bug case where players have no time on a character but get a dropdown in
        #competitive career stats with a time played = "--" like
        #https://playoverwatch.com/en-us/career/pc/burritoh-1532 on 1/28/2018 7:25am PST
        elif "-" in val:
            val = 0
        #Process integers without ,'s
        else:
            val = int(val.replace(",", ""))
        #Add kvp
        info[key] = val

def td_to_feat(td_str):
    """
    Converts strings to lowercase and replaces single spaces with _
    td_to_feat("Pulse Bomb Kills") returns pulse_bomb_kills
    """
    return "_".join(td_str.lower().split(" "))
def td_to_feat_list(td_str_list):
    """
    Same as td_to_feat but for lists. Not including in same function because
    td_to_feat will be called MANY times, whereas this will be called a few times.
    """
    for i in range(len(td_str_list)):
        td_str_list[i] = "_".join(td_str_list[i].lower().split(" "))

# %% [markdown]
# ### Hero HTML Handlers

# %% [markdown]
# This code block is responsible for filling entry values for scraped battletags. The import part is in fill_entries().

# %%
combat_entries = [
    "ELIMINATIONS",
    "DEATHS",
    "FINAL BLOWS",
    "SOLO KILLS",
    "ALL DAMAGE DONE",
    "OBJECTIVE KILLS",
    #" SECONDS" was added and is necessary to avoid adding
    #"OBJECTIVE TIME" back later when misising features are
    #added and 0 filled. This feature isn't missing, it's just
    #appended with _seconds during syntax time.
    "OBJECTIVE TIME SECONDS",
    "MULTIKILLS",
    "ENVIRONMENTAL KILLS",
    "MELEE FINAL BLOWS",
    #" SECONDS" was added and is necessary to avoid adding
    #"TIME SPENT ON FIRE" back later when misising features are
    #added and 0 filled. This feature isn't missing, it's just
    #appended with _seconds during syntax time.
    "TIME SPENT ON FIRE SECONDS",
    "CRITICAL HITS",
    "HERO DAMAGE DONE",
    "BARRIER DAMAGE DONE",
    "QUICK MELEE ACCURACY",
    "CRITICAL HIT ACCURACY",
    "WEAPON ACCURACY"
]
assist_entries = [
    "TELEPORTER PADS DESTROYED",
    "TURRETS DESTROYED",
    "RECON ASSISTS",#specific to widow, hanzo, or any character with wall hack abilities
    "RECON ASSISTS - MOST IN GAME",
    "OFFENSIVE ASSISTS",
    "OFFENSIVE ASSISTS - MOST IN GAME",
    "DEFENSIVE ASSISTS",
    "DEFENSIVE ASSISTS - MOST IN GAME",
    "HEALING DONE",
    "HEALING DONE - MOST IN GAME"#ignore 3 averages for offensive assists, healing done, defensive assists
]
best_entries = [
    "ELIMINATIONS - MOST IN LIFE",
    "ALL DAMAGE DONE - MOST IN LIFE",
    "WEAPON ACCURACY - BEST IN GAME",
    "KILL STREAK - BEST",
    "ALL DAMAGE DONE - MOST IN GAME",
    "ELIMINATIONS - MOST IN GAME",
    "FINAL BLOWS - MOST IN GAME",
    "OBJECTIVE KILLS - MOST IN GAME",
    #" SECONDS" was added and is necessary to avoid adding
    #"OBJECTIVE TIME" back later when misising features are
    #added and 0 filled. This feature isn't missing, it's just
    #appended with _seconds during syntax time.
    "OBJECTIVE TIME - MOST IN GAME SECONDS",
    "MULTIKILL - BEST",
    "SOLO KILLS - MOST IN GAME",
    "CRITICAL HITS - MOST IN GAME",
    "CRITICAL HITS - MOST IN LIFE",
    "MELEE FINAL BLOWS - MOST IN GAME",
    #" SECONDS" was added and is necessary to avoid adding
    #"TIME SPENT ON FIRE" back later when misising features are
    #added and 0 filled. This feature isn't missing, it's just
    #appended with _seconds during syntax time.
    "TIME SPENT ON FIRE - MOST IN GAME SECONDS",
    "HERO DAMAGE DONE - MOST IN GAME",
    "HERO DAMAGE DONE - MOST IN LIFE",
    "BARRIER DAMAGE DONE - MOST IN GAME"
]
#ignore averages
match_awards_entries = [
    "MEDALS - BRONZE",
    "MEDALS - SILVER",
    "MEDALS - GOLD",
    "MEDALS",
    "CARDS"
]
game_entries = [
    "TIME PLAYED",
    "GAMES PLAYED",
    "GAMES WON",
    "GAMES TIED",
    "GAMES LOST",
    "WIN PERCENTAGE"
]
miscellaneous_entries = [
    "shield_generators_destroyed"
]
#Convert entries to correct style
for l in [
    combat_entries,
    assist_entries,
    #best_entries,
    match_awards_entries,
    game_entries,
    miscellaneous_entries
]:
    td_to_feat_list(l)

#Used for ensuring all keys are present after scraping
#(some keys can be missing for 0-valued features)
general_entries = [
    combat_entries,
    assist_entries,
    #best_entries,
    match_awards_entries,
    game_entries,
    miscellaneous_entries
]

def fill_entries(tbodies, info, hero_key):
    """
    Gets the general tbody table entries for each of the 7 information
    tables. Fills in missing values where needed with 0 while ignoring average
    and other incorrect data entries.
    """
    #Get h5s
    h5s = []
    for i in range(len(tbodies)):
        h5s.append(tbodies[i].previous_sibling.find("h5").getText())
    #Remove averages and best tbody
    for i in range(len(h5s)):
        if h5s[i] == u'Average' or h5s[i] == u'Best':
            h5s[i] = ""
    tmp_list = []
    for i in range(len(h5s)):
        if h5s[i] != "":
            tmp_list.append(tbodies[i])
    tbodies = tmp_list
    
    #Handle edge case for Winston Miscellaneous tbody having conflicting
    #elements with Hero Specific tbody
    #print(hero_data_category_id_to_hero_specific[hero_key]["name"])
    if hero_key != hero_to_hash["winston"]:
        #Add information for relevant tbodies
        for i in range(0, len(tbodies)):
            add_keys_from_tbody(tbodies[i], info)
    else:
        #Iterating backwards will have the Melee Kills field written twice.
        #However, the problematic entry will be overwritten (it's written
        #first), so it fixes the incorrect value issue. However, at the
        #end of this function remember to delete winston-specific
        #miscellaneous fields
        for i in range(len(tbodies) - 1, -1, -1):
            add_keys_from_tbody(tbodies[i], info)

    #Pluralize
    pluralize(info, hero_key)
    
    #Add missing general entries
    for entry_list in general_entries:
        for k in entry_list:
            if k not in info:
                info[k] = 0
    #Add missing hero specific
    for k in hero_data_category_id_to_hero_specific[hero_key]["entries"]:
        if k not in info:
            info[k] = 0
            
    #Delete any key containing the word average or avg
    keys_to_delete = []
    for k in info:
        if "average" in k or "avg" in k:
            keys_to_delete.append(k)
    for k in keys_to_delete:
        del info[k]
    
    #Fix any key like
    #NANO {COUNT, PLURAL, ONE {BOOST} OTHER {BOOSTS}} APPLIED - MOST IN GAME
    #nano_{count,_plural,_one_{boost}_other_{boosts}}_applied_-_most_in_game
    #Keys to fix will hold tuples of the (old key, new key)
    keys_to_fix = []
    for k in info:
        end_idx = k.find("}}")
        #Match found
        if end_idx != -1:
            val_str = ""
            #Trace string backwards
            back_idx = end_idx
            while True:
                back_idx -= 1
                #Stop if reached last opening brace
                if k[back_idx] == "{":
                    break
                #Build string backwards
                else:
                    val_str = k[back_idx] + val_str
            
            #The desired characters are in val_str
            new_key = k[:k.find("{")] + val_str + k[end_idx+2:]
            keys_to_fix.append((k, new_key))
    #Add new fixed keys and remove old broken ones
    for k_tup in keys_to_fix:
        info[k_tup[1]] = info[k_tup[0]]
        del info[k_tup[0]]
        
    #One player had a unique key on Bastion that looked like some hash value with
    #a "." in it and a bunch of numbers. Will just remove any key with a . in it
    fucked_keys = []
    for k in info:
        if "." in k:
            fucked_keys.append(k)
    for k in fucked_keys:
        del info[k]
            
    #Delete time_played object_time keys (replaced by " "_seconds)
    del info["time_played"]
    #del info["objective_time"]
    #del info["objective_time_-_most_in_game"]
    #del info["time_spent_on_fire"]
    #del info["time_spent_on_fire_-_most_in_game"]
    
    #Delete hero specific keys for most/best in game
    fucked_keys = []
    for k in info:
        if k.endswith("in_game"):
            fucked_keys.append(k)
    for k in fucked_keys:
        del info[k]
    
    #Delete recon assists for all characters except hanzo, widow, and genji (can deflect sonar i think)
    if not (hero_key == "0x02E0000000000029" or hero_key == "0x02E0000000000005" or hero_key == "0x02E000000000000A"):
        del info["recon_assists"]
    #Delete winston Miscellaneous attributes
    if hero_key == hero_to_hash["winston"]:
        if "jump_kills" in info:
            del info["jump_kills"]
        if "weapon_kills" in info:
            del info["weapon_kills"]
    #Replace symmetra shield generators (incorrectly pluralized if they have shield generator
    #uptime from Shield Generators Destroyed attribute for General Features) uptime
    if hero_key == hero_to_hash["symmetra"]:
        if "shield_generators_uptime" in info:
            info["shield_generator_uptime"] = info["shield_generators_uptime"]
            del info["shield_generators_uptime"]
        if "sentry_turrets_kills" in info:
            info["sentry_turret_kills"] = info["sentry_turrets_kills"]
            del info["sentry_turrets_kills"]
    
    #Delete deflected dragonstrike and graviton surge kills for genji
    #Note: May have to do others like tac visor, concussion mine, etc.
    if hero_key == hero_to_hash["genji"]:
        if "graviton_surge_kills" in info:
            del info["graviton_surge_kills"]
        if "dragonstrike_kills" in info:
            del info["dragonstrike_kills"]
    
    #Replace any singular medal or game keys
    mg_replace_tups = [("medal", "medals"), ("game", "games")]
    mg_singular_lists = [
        ["medal_-_bronze", "medal_-_silver", "medal_-_gold", "medal"],
        ["game_won", "game_played", "game_lost"]
    ]
    for i in range(2):
        ls = mg_singular_lists[i]
        for j in range(len(ls)):
            if ls[j] in info:
                new_key = ls[j].replace(mg_replace_tups[i][0], mg_replace_tups[i][1])
                info[new_key] = info[ls[j]]
                del info[ls[j]]

# %% [markdown]
# #### Hero Specific Entries
# This is just a listing of what each hero *should* have in terms of hero-specific features.

# %%
hero_data_category_id_to_hero_specific = {
    #Ana
    "0x02E000000000013B": {
        "name": "ana",
        "entries": [
            "SCOPED ACCURACY - BEST IN GAME",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME",
            "ENEMIES SLEPT",
            "NANO BOOSTS APPLIED",
            "NANO BOOST ASSISTS",
            "UNSCOPED ACCURACY - BEST IN GAME",
            "ENEMIES SLEPT - MOST IN GAME",
            "NANO BOOST ASSISTS - MOST IN GAME",
            #NANO {COUNT, PLURAL, ONE {BOOST} OTHER {BOOSTS}} APPLIED - MOST IN GAME regex
            "BIOTIC GRENADE KILLS",
            "SCOPED ACCURACY",
            "UNSCOPED_ACCURACY"
        ]
    },
    #Bastion
    "0x02E0000000000015": {
        "name": "bastion",
        "entries": [
            "RECON KILLS",
            "SENTRY KILLS",
            "TANK KILLS",
            "SENTRY KILLS - MOST IN GAME",
            "RECON KILLS - MOST IN GAME",
            "TANK KILLS - MOST IN GAME",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME"
            #OVERWATCH.GUID.0X0860000000000033
        ]
    },
    #Doomfist
    "0x02E000000000012F": {
        "name": "doomfist",
        "entries": [
            "ABILITY DAMAGE DONE",
            "ABILITY DAMAGE DONE - MOST IN GAME",
            "METEOR STRIKE KILLS",
            "METEOR STRIKE KILLS - MOST IN GAME",
            "SHIELDS CREATED",
            "SHIELDS CREATED - MOST IN GAME"
        ]
    },
    #D.Va
    "0x02E000000000007A": {
        "name": "d.va",
        "entries": [
            "SELF-DESTRUCT KILLS",
            "SELF-DESTRUCT KILLS - MOST IN GAME",
            "MECHS CALLED",
            "MECHS CALLED - MOST IN GAME",
            "DAMAGE BLOCKED - MOST IN GAME",
            "DAMAGE BLOCKED",
            "MECH DEATHS"
        ]
    },
    #Genji
    "0x02E0000000000029": {
        "name": "genji",
        "entries": [
            "DRAGONBLADE KILLS",
            "DRAGONBLADE KILLS - MOST IN GAME",
            "DAMAGE REFLECTED",
            "DAMAGE REFLECTED - MOST IN GAME",
            "DRAGONBLADES"
        ]
    },
    #Hanzo
    "0x02E0000000000005": {
        "name": "hanzo",
        "entries": [
            "DRAGONSTRIKE KILLS",
            "DRAGONSTRIKE KILLS - MOST IN GAME",
            "SCATTER ARROW KILLS",
            "SCATTER ARROW KILLS - MOST IN GAME"
        ]
    },
    #Junkrat
    "0x02E0000000000065": {
        "name": "junkrat",
        "entries": [
            "ENEMIES TRAPPED - MOST IN GAME",
            "ENEMIES TRAPPED",
            "RIP-TIRE KILLS - MOST IN GAME",
            "RIP-TIRE KILLS",
            "CONCUSSION MINE KILLS",
            "CONCUSSION MINE KILLS - MOST IN GAME"
        ]
    },
    #Lucio
    "0x02E0000000000079": {
        "name": "lucio",
        "entries": [
            "SOUND BARRIERS PROVIDED",
            "SOUND BARRIERS PROVIDED - MOST IN GAME",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME"
        ]
    },
    #McCree
    "0x02E0000000000042": {
        "name": "mccree",
        "entries": [
            "DEADEYE KILLS",
            "DEADEYE KILLS - MOST IN GAME",
            "FAN THE HAMMER KILLS",
            "FAN THE HAMMER KILLS - MOST IN GAME"
        ]
    },
    #Mei
    "0x02E00000000000DD": {
        "name": "mei",
        "entries": [
            "ENEMIES FROZEN",
            "ENEMIES FROZEN - MOST IN GAME",
            "BLIZZARD KILLS - MOST IN GAME",
            "BLIZZARD KILLS",
            "DAMAGE BLOCKED - MOST IN GAME",
            "DAMAGE BLOCKED",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME"
        ]
    },
    #Mercy
    "0x02E0000000000004": {
        "name": "mercy",
        "entries": [
            "BLASTER KILLS",
            "BLASTER KILLS - MOST IN GAME",
            "PLAYERS RESURRECTED",
            "PLAYERS RESURRECTED - MOST IN GAME",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME",
            "DAMAGE AMPLIFIED",
            "DAMAGE AMPLIFIED - MOST IN GAME"
        ]        
    },
    #Moira
    "0x02E00000000001A2": {
        "name": "moira",
        "entries": [
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME",
            "COALESCENCE KILLS",
            "COALESCENCE KILLS - MOST IN GAME",
            "COALESCENCE HEALING",
            "COALESCENCE HEALING - MOST IN GAME",
            "SECONDARY FIRE ACCURACY"
        ]
    },
    #Orisa
    "0x02E000000000013E": {
        "name": "orisa",
        "entries": [
            "DAMAGE AMPLIFIED",
            "DAMAGE AMPLIFIED - MOST IN GAME",
            "DAMAGE BLOCKED",
            "DAMAGE BLOCKED - MOST IN GAME",
            "SUPERCHARGER ASSISTS",
            "SUPERCHARGER ASSISTS - MOST IN GAME"
        ]
    },
    #Pharah
    "0x02E0000000000008": {
        "name": "pharah",
        "entries": [
            "ROCKET DIRECT HITS",
            "BARRAGE KILLS",
            "ROCKET DIRECT HITS - MOST IN GAME",
            "BARRAGE KILLS - MOST IN GAME"
        ]
    },
    #Reaper
    "0x02E0000000000002": {
        "name": "reaper",
        "entries": [
            "DEATH BLOSSOM KILLS",
            "DEATH BLOSSOM KILLS - MOST IN GAME",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME"
        ]
    },
    #Reinhardt
    "0x02E0000000000007": {
        "name": "reinhardt",
        "entries": [
            "DAMAGE BLOCKED",
            "DAMAGE BLOCKED - MOST IN GAME",
            "CHARGE KILLS",
            "CHARGE KILLS - MOST IN GAME",
            "FIRE STRIKE KILLS",
            "FIRE STRIKE KILLS - MOST IN GAME",
            "EARTHSHATTER KILLS",
            "EARTHSHATTER KILLS - MOST IN GAME",
            "ROCKET HAMMER MELEE ACCURACY"
        ]
    },
    #Roadhog
    "0x02E0000000000040": {
        "name": "roadhog",
        "entries": [
            "ENEMIES HOOKED - MOST IN GAME",
            "ENEMIES HOOKED",
            "HOOKS ATTEMPTED",
            "WHOLE HOG KILLS - MOST IN GAME",
            "WHOLE HOG KILLS",
            "HOOK ACCURACY - BEST IN GAME",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME",
            "HOOK ACCURACY"
        ]
    },
    #Soldier: 76
    "0x02E000000000006E": {
        "name": "soldier76",
        "entries": [
            "HELIX ROCKETS KILLS - MOST IN GAME",
            "HELIX ROCKETS KILLS",#pluralize rocket
            "TACTICAL VISOR KILLS",
            "TACTICAL VISOR KILLS - MOST IN GAME",
            "BIOTIC FIELDS DEPLOYED",#pluralize field
            "BIOTIC FIELD HEALING DONE",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME"
        ]
    },
    #Sombra
    "0x02E000000000012E": {
        "name": "sombra",
        "entries": [
            "ENEMIES HACKED",
            "ENEMIES EMP'D",
            "ENEMIES HACKED - MOST IN GAME",
            "ENEMIES EMP'D - MOST IN GAME"
        ]
    },
    #Symmetra
    "0x02E0000000000016": {
        "name": "symmetra",
        "entries": [
            "SENTRY TURRET KILLS",
            "SENTRY TURRET KILLS - MOST IN GAME",
            "PLAYERS TELEPORTED",#pluralize player
            "PLAYERS TELEPORTED - MOST IN GAME",
            "TELEPORTER UPTIME",
            "TELEPORTER UPTIME - BEST IN GAME",
            "DAMAGE BLOCKED",
            "DAMAGE BLOCKED - MOST IN GAME",
            "SHIELD GENERATOR UPTIME",
            "PRIMARY FIRE ACCURACY"
        ]
    },
    #Torbjorn
    "0x02E0000000000006": {
        "name": "torbjorn",
        "entries": [
            "ARMOR PACKS CREATED",
            #NOTE: This is a pain in the ass. These are different
            #characters and we're using ö.
            #Ö is not the same as what we're using.
            #Second NOTE: Those both suck try this instead: \xf6. I really
            #swear the big o with the dots worked yesterday lmao.
            #Third NOTE: No good
            "TORBJÖRN KILLS",
            "TURRET KILLS",
            "TORBJÖ6RN KILLS - MOST IN GAME",
            "ARMOR PACKS CREATED - MOST IN GAME",
            "TURRET KILLS - MOST IN GAME",
            "MOLTEN CORE KILLS",
            "MOLTEN CORE KILLS - MOST IN GAME"
        ]
    },
    #Tracer
    "0x02E0000000000003": {
        "name": "tracer",
        "entries": [
            "PULSE BOMB KILLS",
            "PULSE BOMB KILLS - MOST IN GAME",
            "PULSE BOMBS ATTACHED - MOST IN GAME",
            "PULSE BOMBS ATTACHED",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME",
            "HEALTH RECOVERED",
            "HEALTH RECOVERED - MOST IN GAME",
        ]
    },
    #Widowmaker
    "0x02E000000000000A": {
        "name": "widowmaker",
        "entries": [
            "VENOM MINE KILLS",
            "SCOPED CRITICAL HITS",
            "SCOPED CRITICAL HITS - MOST IN GAME",
            "VENOM MINE KILLS - MOST IN GAME",
            "SCOPED ACCURACY"
        ]
    },
    #Winston
    "0x02E0000000000009": {
        "name": "winston",
        "entries": [
            "PLAYERS KNOCKED BACK",
            "DAMAGE BLOCKED",
            "DAMAGE BLOCKED - MOST IN GAME",
            "PLAYERS KNOCKED BACK - MOST IN GAME",
            "MELEE KILLS",
            "MELEE KILLS - MOST IN GAME",
            "JUMP PACK KILLS",
            "JUMP PACK KILLS - MOST IN GAME",
            "PRIMAL RAGE KILLS",
            "PRIMAL RAGE KILLS - MOST IN GAME",
            "PRIMAL RAGE MELEE ACCURACY",
            "TESLA CANNON ACCURACY"
        ]
    },
    #Zarya
    "0x02E0000000000068": {
        "name": "zarya",
        "entries": [
            "DAMAGE BLOCKED",
            "DAMAGE BLOCKED - MOST IN GAME",
            "GRAVITON SURGE KILLS",
            "GRAVITON SURGE KILLS - MOST IN GAME",
            "HIGH ENERGY KILLS - MOST IN GAME",
            "HIGH ENERGY KILLS",
            "PROJECTED BARRIERS APPLIED",
            "AVERAGE ENERGY - BEST IN GAME",
            "PROJECTED BARRIERS APPLIED - MOST IN GAME",
            "AVERAGE ENERGY",
            "PRIMARY FIRE ACCURACY"
        ]
    },
    #Zenyatta
    "0x02E0000000000020": {
        "name": "zenyatta",
        "entries": [
            "TRANSCENDENCE HEALING - BEST",
            "TRANSCENDENCE HEALING",
            "SELF HEALING",
            "SELF HEALING - MOST IN GAME"
        ]
    }
}

for k,v in hero_data_category_id_to_hero_specific.iteritems():
    td_to_feat_list(v["entries"])
#Doing this here because I don't feel like going through and fixing
#they syntax by hand
for k,v in hero_data_category_id_to_hero_specific.iteritems():
    entry_map = {}
    for entry in v["entries"]:
        entry_map[entry] = 1
    hero_data_category_id_to_hero_specific[k]["entries"] = entry_map
    
#Map hero names to data-category-id
hero_to_hash = {}
for k,v in hero_data_category_id_to_hero_specific.iteritems():
    hero_to_hash[v["name"]] = k

# %% [markdown]
# #### Hero Data Extractor
# This code block contains the function responsible for managing the extraction of hero entries every possible hero. If a hero is not in the competitive profile on the HTML page, it's skipped.

# %%
def hero_data_extractor(comp_soup):
    """
    Extracts data from specified BeautifulSoup competitive div for all
    heroes available through PlayOverwatch for the player under consideration.
    
    Returns a list of (hero_name, hero_dictionary) tuples.
    """
    hero_infos = []
    for hero_key in hero_data_category_id_to_hero_specific:
        #Get hero specific data
        hero_soup = comp_soup.find("div", {"data-category-id": hero_key})
        if hero_soup != None:
            info = {}
            tbodies = hero_soup.find_all("tbody")
            fill_entries(tbodies, info, hero_key)
            #Weird bug where player isn't reported to have time on a character but
            #but has a dropdown in competitive career stats
            #https://playoverwatch.com/en-us/career/pc/slin-1353 Lucio for 1/28/2018 7:07AM PST
            if "time_played_seconds" not in info:
                continue
            
            original_info = handle_averages(info, hero_key)
            
            hero_infos.append((hero_data_category_id_to_hero_specific[hero_key]["name"], info, original_info))
    return hero_infos

# %% [markdown]
# #### Pluralizer
# This code block is only responsible for pluralizing features. For most features on PlayOverwatch, they use pluralizing JS to make entries end in s for integer values > 1. Features corresponding with a value of 1 do not get an s added, which causes great difficulties for words like enemy vs. enemies, etc..

# %%
#Ends with keys
ends_with = ["kill", "blow", "death", "elimination", "hit", "assist", "card", "medal"]
len_ends_with = len(ends_with)
#Contains keys
contains = ["generator", "pad", "turret", "assist"]
len_contains = len(contains)
    
#Special cases (instances for hero-specific information that doesn't need to be checked
#for all heroes). Probably could be done better, but it's not a priority right now.
problem_keys_to_phrases = {
    #Ana
    "0x02E000000000013B":
        [
            ("enemies_slept", "enemy_slept", 1),
            ("nano_boosts_applied", "nano_boost_applied", 1)
        ],
    #Doomfist
    "0x02E000000000012F":
        [("shields_created", "shield_created", 1)],
    #D.Va
    "0x02E000000000007A":
        [
            ("mechs_called", "mech_called", 1),
            ("mech_deaths", "mech_death", 1)
        ],
    #Genji
    "0x02E0000000000029":
        [("dragonblades", "dragonblade", 1)],
    #Junkrat
    "0x02E0000000000065":
        [("enemies_trapped", "enemy_trapped", 1)],
    #Lucio
    "0x02E0000000000079":
        [("sound_barriers_provided", "sound_barrier_provided", 1)],
    #Mei
    "0x02E00000000000DD":
        [("enemies_frozen", "enemy_frozen", 1)],
    #Mercy
    "0x02E0000000000004":
        [("players_resurrected", "player_resurrected", 1)],
    #Roadhog
    "0x02E0000000000040":
        [
            ("enemies_hooked", "enemy_hooked", 1),
            ("hooks_attempted", "hook_attempted", 1)
        ],
    #Soldier: 76
    "0x02E000000000006E":
        [
            ("biotic_fields_deployed", "biotic_field_deployed", 1),
            ("helix_rockets_kills", "helix_rocket_kills", 1)
        ],
    #Sombra
    "0x02E000000000012E":
        [
            ("enemies_hacked", "enemy_hacked", 1),
            ("enemies_emp'd", "enemy_emp'd", 1)
        ],
    #Symmetra
    "0x02E0000000000016":
        #Preferred phrase, occuring phrase, number of possible occurences
        [("players_teleported", "player_teleported", 1)],
    #Torbjorn
    "0x02E0000000000006":
        [("armor_packs_created", "armor_pack_created", 1)],
    #Tracer
    "0x02E0000000000003":
        [("pulse_bombs_attached", "pulse_bomb_attached", 1)],
    #Winston
    "0x02E0000000000009":
        [("players_knocked_back", "player_knocked_back", 1)],
    #Zarya
    "0x02E0000000000068":
        [("projected_barriers_applied", "projected_barrier_applied", 1)]
}

def pluralize(info, hero_key):
    """
    Pluralizes any of the following words (if not already plural) in the info
    dictionary where necessary (if the word is the last word in a key):
    kill, blow, death, elimination, hit, assist, generator, pad, game, card, medal, turret
    """
    #Tuple lists of (k,v) to update AFTER iterating through the dictionary
    kvps_end_with = []
    kvps_contains = []
    for k,v in info.iteritems():
        does_end_with = False
        #Check ends with
        for i in range(0, len_ends_with):
            if k.endswith(ends_with[i]):
                kvps_end_with.append((k,v))
                does_end_with = True
                break
            elif k.endswith("_in_game"):
                break
        if does_end_with:
            continue
        
        #Check contains
        for i in range(0, len_contains):
            #If it is already pluralized, don't replace pads with padss
            #valid example below
            #if pad in "teleporter pad destroyed" and pads not in "teleporter pad destroyed"
            if (contains[i] in k) and ((contains[i] + "s") not in k):
                kvps_contains.append((k,v,i))
                break
                
    #Pluralize keys
    for tup in kvps_end_with:
        info[tup[0] + "s"] = tup[1]
        del info[tup[0]]
    for tup in kvps_contains:
        info[tup[0].replace(contains[tup[2]], contains[tup[2]] + "s")] = tup[1]
        del info[tup[0]]
    
    #Only do work if this hero is known to have an issue
    if hero_key in problem_keys_to_phrases:
        #Holds tuples of (key, phrase_tup)
        erase_tups = []
        phrase_tups = problem_keys_to_phrases[hero_key]
        
        ##
        """
        for phrase_tup in phrase_tups:
            count = 0
            for k in info:
                if (phrase_tup[1] in k) and ((phrase_tup[0]) not in k):
                    count += 1
                    erase_tups.append((k, phrase_tup))
                if count == phrase_tup[2]:
                    break
            
        for erase_tup in erase_tups:
            phrase_tup = erase_tup[1]#phrase_tup is a tuple itself, erase_tup is a (string, tuple) tuple
            origin_key = erase_tup[0]
            info[origin_key.replace(phrase_tup[1], phrase_tup[0])] = info[origin_key]
            del info[origin_key]
        """
        ##
        swap_keys = []
        for phrase_tup in phrase_tups:
            if phrase_tup[1] in info:
                swap_keys.append((phrase_tup[0], phrase_tup[1]))
        for key_tup in swap_keys:
            info[key_tup[0]] = info[key_tup[1]]
            del info[key_tup[1]]

# %% [markdown]
# #### Average Maps
# If an entry is in one of these map, it has to be averaged before writing to file.

# %%
#Per life and second stats
per_life_and_second_average_map = {}
#Hero Specific
for k,v in hero_data_category_id_to_hero_specific.iteritems():
    for entry in v["entries"]:
        if not entry.endswith("best") and not entry.endswith("game") and not entry.endswith("energy") and not entry.endswith("accuracy"):
            per_life_and_second_average_map[entry] = 1
#General
for entry_list in [combat_entries, assist_entries, miscellaneous_entries]:
    for entry in entry_list:
        if not entry.endswith("game") and not entry.endswith("accuracy") and not entry.endswith("deaths"):
            per_life_and_second_average_map[entry] = 1
#Handle Torbjorn fancy o's
per_life_and_second_average_map["torbjorn_kills"] = 1

#Per game stats
per_game_average_map = {}
for entry_list in [match_awards_entries]:
    for entry in entry_list:
        per_game_average_map[entry] = 1

# %% [markdown]
# #### Hero Specific Average Helpers
# These methods just return true or false if the hero name meets a criteria.

# %%
#Healing data is not recorded for Sombra on PlayOverwatch
healer_names = ["ana", "lucio", "mercy", "moira", "soldier76", "zenyatta"]
def is_healer(hero_key):
    """
    Returns True if the specified hero key can be referred to as a healer.
    """
    for h in healer_names:
        if hero_key == hero_to_hash[h]:
            return True
    return False

blocker_names = ["mei", "symmetra", "d.va", "orisa", "reinhardt", "winston", "zarya"]
def is_blocker(hero_key):
    """
    Returns True if the specified hero key can block damage.
    """
    for b in blocker_names:
        if hero_key == hero_to_hash[b]:
            return True
    return False

booper_names = ["lucio", "pharah", "roadhog", "orisa", "winston", "doomfist", "d.va", "junkrat"]
def is_booper(hero_key):
    """
    Returns True if the specified hero key can boop (no Reinhardt).
    """
    for b in booper_names:
        if hero_key == hero_to_hash[b]:
            return True
    return False

# %% [markdown]
# #### Average Handler
# Averages all necessary features prior to file output.

# %%
def handle_averages(info, hero_key):
    """
    Reclaculates running sum measurements into an average based on total number of lives (deaths + 1). 
    """
    #Torb's fancy o's (Ö) cause an issue with working with strings...this can be solved
    #by uncommenting the Handle utf-8 section. However, uncommenting this section forces
    #jupyter to output everything to the command promopt as opposed to under the executed
    #cell. It's best to comment out this torb section unless scraping.
    #Replace o's
    #Update: This problem blows let me do it my way k thanks.
    if hero_key == hero_to_hash["torbjorn"]:
        torb_keys = []
        for k in info:
            if k.endswith("rn_kills"):
                torb_keys.append(k)
        max_torb_val = -1
        for k in torb_keys:
            if max_torb_val < info[k]:
                max_torb_val = info[k]
            del info[k]
        info["torbjorn_kills"] = max_torb_val
        
        #If turrets was accidnetally pluralized because of "Turrets Destroyed"
        #feature pluralization from "Turret Destroyed"
        if "turrets_kills" in info:
            info["turret_kills"] = info["turrets_kills"]
            del info["turrets_kills"]
        
    
    #Cloning original info for output to raw (original data minus some problematic features) data
    original_data = {}
    for k in info:
        original_data[k] = info[k]
    
    #Calculate averages based on time played and lifes
    per_life_and_second_keys = []
    lifes = int(info["deaths"]) + 1.0#lmao lives is unclear
    #print(hero_data_category_id_to_hero_specific[hero_key]["name"])
    seconds = 1.0 * max(info["time_played_seconds"], 1)
    for k in info:
        if k in per_life_and_second_average_map:
            per_life_and_second_keys.append(k)
    for k in per_life_and_second_keys:
        #Stats per life
        info[k + "_per_life"] = info[k] / lifes
        #Stats per second
        #avoid divide by 0 in strange case where data was scraped for a
        #hero with a time played = 0 seconds
        info[k + "_per_second"] = info[k] / seconds
    
    #Calculates averages based on games played
    per_game_keys = []
    games = 1.0 * max(info["games_played"], 1)
    for k in info:
        if k in per_game_average_map:
            per_game_keys.append(k)
    for k in per_game_keys:
        info[k + "_per_game"] = info[k] / games
        
    #General custom averages
    elims = 1.0 * max(info["eliminations"], 1)
    info["final_blows_per_elimination"] = info["final_blows"] / elims
    info["solo_kills_per_elimination"] = info["solo_kills"] / elims
    info["objective_kills_per_elimination"] = info["objective_kills"] / elims
    info["hero_to_barrier_damage_ratio"] = info["hero_damage_done"] / float(max(info["barrier_damage_done"], 1))
    info["average_life"] = seconds / lifes
    
    #Role specific averages
    damage = 1.0 * max(info["all_damage_done"], 1)
    #Healers
    if is_healer(hero_key):
        info["healing_to_damage_ratio"] = info["healing_done"] / damage
    #Blockers
    if is_blocker(hero_key):
        info["damage_blocked_to_output_ratio"] = info["damage_blocked"] / damage
    #Boopers
    if is_booper(hero_key):
        info["environmental_kills_to_eliminations_ratio"] = info["environmental_kills"] / elims
    
    #Hero specific averages
    #Ana
    if hero_key == hero_to_hash["ana"]:
        info["grenade_kills_to_eliminations_ratio"] = info["biotic_grenade_kills"] / elims
        info["nano_assists_to_applied_ratio"] = info["nano_boost_assists"] / float(max(info["nano_boosts_applied"], 1))
    #Bastion
    elif hero_key == hero_to_hash["bastion"]:
        info["recon_kills_to_eliminations_ratio"] = info["recon_kills"] / elims
        info["sentry_kills_to_eliminations_ratio"] = info["sentry_kills"] / elims
        info["tank_kills_to_eliminations_ratio"] = info["tank_kills"] / elims
    #Doomfist
    elif hero_key == hero_to_hash["doomfist"]:
        info["meteor_strike_kills_to_eliminations_ratio"] = info["meteor_strike_kills"] / elims
    #D.Va
    elif hero_key == hero_to_hash["d.va"]:
        info["self-destruct_kills_to_eliminations_ratio"] = info["self-destruct_kills"] / elims
        info["mech_deaths_to_deaths_ratio"] = info["mech_deaths"] / float(max(info["deaths"], 1))
    #Genji
    elif hero_key == hero_to_hash["genji"]:
        info["dragonblade_kills_to_eliminations_ratio"] = info["dragonblade_kills"] / elims
        info["damage_reflected_to_output_ratio"] = info["damage_reflected"] / damage
        info["dragonblade_kills_to_dragonblades_ratio"] = info["dragonblade_kills"] / float(max(info["dragonblades"], 1))
    #Hanzo
    elif hero_key == hero_to_hash["hanzo"]:
        info["dragonstrike_kills_to_eliminations_ratio"] = info["dragonstrike_kills"] / elims
        info["scatter_arrow_kills_to_eliminations_ratio"] = info["scatter_arrow_kills"] / elims
    #Junkrat
    elif hero_key == hero_to_hash["junkrat"]:
        info["enemies_trapped_to_eliminations_ratio"] = info["enemies_trapped"] / elims
        info["rip-tire_kills_to_eliminations_ratio"] = info["rip-tire_kills"] / elims
        info["concussion_mine_kills_to_eliminations_ratio"] = info["concussion_mine_kills"] / elims
    #Lucio
    elif hero_key == hero_to_hash["lucio"]:
        info["healing_done_to_self_healing_ratio"] = info["healing_done"] / float(max(info["self_healing"], 1))
    #McCree
    elif hero_key == hero_to_hash["mccree"]:
        info["deadeye_kills_to_eliminations_ratio"] = info["deadeye_kills"] / elims
        info["fan_the_hammer_kills_to_eliminations_ratio"] = info["fan_the_hammer_kills"] / elims
    #Mei
    elif hero_key == hero_to_hash["mei"]:
        info["enemies_frozen_to_eliminations_ratio"] = info["enemies_frozen"] / elims
        info["blizzard_kills_to_eliminations_ratio"] = info["blizzard_kills"] / elims
    #Mercy
    elif hero_key == hero_to_hash["mercy"]:
        info["damage_amplified_to_healing_done"] = info["damage_amplified"] / float(max(info["healing_done"], 1))
    #Moira
    elif hero_key == hero_to_hash["moira"]:
        info["coalescence_kills_to_eliminations_ratio"] = info["coalescence_kills"] / elims
        info["coalescence_healing_to_healing_done"] = info["coalescence_healing"] / float(max(info["healing_done"], 1))
    #Orisa
    #Pharah
    elif hero_key == hero_to_hash["pharah"]:
        info["barrage_kills_to_eliminations_ratio"] = info["barrage_kills"] / elims
    #Reaper
    elif hero_key == hero_to_hash["reaper"]:
        info["death_blossom_kills_to_eliminations_ratio"] = info["death_blossom_kills"] / elims
    #Reinhardt
    elif hero_key == hero_to_hash["reinhardt"]:
        info["charge_kills_to_eliminations"] = info["charge_kills"] / elims
        info["fire_strike_kills_to_eliminations"] = info["fire_strike_kills"] / elims
        info["earthshatter_kills_to_eliminations"] = info["earthshatter_kills"] / elims
    #Roadhog
    elif hero_key == hero_to_hash["roadhog"]:
        info["enemies_hooked_to_eliminations_ratio"] = info["enemies_hooked"] / elims
        info["whole_hog_kills_to_eliminations_ratio"] = info["whole_hog_kills"] / elims
    #Soldier: 76
    elif hero_key == hero_to_hash["soldier76"]:
        info["helix_rockets_kills_to_eliminations_ratio"] = info["helix_rockets_kills"] / elims
        info["tactical_visor_kills_to_eliminations_ratio"] = info["tactical_visor_kills"] / elims
        info["biotic_field_healing_done_to_self_healing_ratio"] = info["biotic_field_healing_done"] / float(max(info["self_healing"], 1))
        info["biotic_field_healing_done_to_biotic_fields_deployed_ratio"] = info["biotic_field_healing_done"] / float(max(info["biotic_fields_deployed"], 1))
    #Sombra
    elif hero_key == hero_to_hash["sombra"]:
        info["enemies_hacked_to_eliminations_ratio"] = info["enemies_hacked"] / elims
        info["enemies_emp'd_to_eliminations_ratio"] = info["enemies_emp'd"] / elims
        info["enemies_hacked_to_enemies_emp'd_ratio"] = info["enemies_hacked"] / float(max(info["enemies_emp'd"], 1))
    #Symmetra
    elif hero_key == hero_to_hash["symmetra"]:
        info["sentry_turret_kills_to_eliminations_ratio"] = info["sentry_turret_kills"] / elims
    #Tracer
    elif hero_key == hero_to_hash["tracer"]:
        info["pulse_bomb_kills_to_eliminations_ratio"] = info["pulse_bomb_kills"] / elims
        info["pulse_bombs_attached_to_pulse_bomb_kills_ratio"] = info["pulse_bombs_attached"] / float(max(info["pulse_bomb_kills"], 1))
    #Widowmaker
    elif hero_key == hero_to_hash["widowmaker"]:
        info["venom_mine_kills_to_eliminations_ratio"] = info["venom_mine_kills"] / elims
    #Winston
    elif hero_key == hero_to_hash["winston"]:
        #Winston gets a miscellaneous entry for all melee and jump pack. The melee
        #entries do not match up. This has been handled in fill_entries()
        info["melee_kills_to_eliminations_ratio"] = info["melee_kills"] / elims
        info["jump_pack_kills_to_eliminations_ratio"] = info["jump_pack_kills"] / elims
        info["primal_rage_kills_to_eliminations_ratio"] = info["primal_rage_kills"] / elims
    #Zarya
    elif hero_key == hero_to_hash["zarya"]:
        info["graviton_surge_kills_to_eliminations_ratio"] = info["graviton_surge_kills"] / elims
        info["high_energy_kills_to_eliminations_ratio"] = info["high_energy_kills"] / elims
    #Zenyatta
    elif hero_key == hero_to_hash["zenyatta"]:
        info["transcendence_healing_to_healing_done_ratio"] = info["transcendence_healing"] / float(max(info["healing_done"], 1))
    #Torbjorn
    #Find matching COMMENT THIS OUT section to comment out import sys code if
    #1. getting ascii character at position errors or
    #2. print() output is being printed to commandline instead of jupyter
#    """
    elif hero_key == hero_to_hash["torbjorn"]:
        info["turret_kills_to_torbjorn_kills_ratio"] = info["turret_kills"] / float(max(info["torbjorn_kills"], 1))
        info["torbjorn_kills_to_eliminations_ratio"] = info["torbjorn_kills"] / elims
        info["turret_kills_to_eliminations_ratio"] = info["turret_kills"] / elims
        info["molten_core_kills_to_eliminations_ratio"] = info["molten_core_kills"] / elims
#    """
    
    #Delete converted keys
    #Note: can't delete keys before creating general/hero specific custom averages
    for l in [per_life_and_second_keys, per_game_keys]:
        for k in l:
            del info[k]
            
    #lul this return statement does not match the function name lmfao
    return original_data

# %% [markdown]
# ### Handle utf-8
# This is necessary because Overwatch has 1 character with a fancy o in his name, Torbjorn. Outputing/working with that string is just a pain in the ass. Unfortunately, running this codeblock forces all output to go to the console but is the only known fix for the issue.

# %%
#Find matching COMMENT THIS OUT section to comment out Torbjorn data if
    #1. getting ascii character at position errors or
    #2. print() output is being printed to commandline instead of jupyter
#"""
import sys
reload(sys)
sys.setdefaultencoding("utf8")
#"""

# %% [markdown]
# ### Scraping function

# %%
def scrape_data_for_battletag(battletag):
    """
    Scrapes and preprocesses the data for a specified battletag from
    Blizzard's PlayOverwatch website. Note this function does not
    write the data to a file.
    
    If a request returns a 504, this function will literally continue to
    sleep and retry forever.
    """
    #Make requestd
    battletag_url = "https://playoverwatch.com/en-us/career/pc/{}"
    
    #Request until 504 turns to 200
    retry_time = 1
    exp_factor = 2
    while True:
        try:
            req = urllib2.Request(
                battletag_url.format("-".join(battletag.split("#"))),
                headers={"User-Agent": "Mozilla/5.0"}
            )
            resp = urllib2.urlopen(req)
            if resp.getcode() == 200:
                break
        except Exception as inst:
            print("Got 504. Sleeping for {}s.".format(retry_time))
            time.sleep(retry_time)
            retry_time *= exp_factor
            print("||||||||||")
            print("||||||||||")
            print("||||||||||")
            print("Retrying {}".format(battletag))
            
    #BeautifulSoup
    soup = bs(resp.read())
    
    #Get current SR
    sr = soup.find("div", {"class": "competitive-rank"})
    if sr == None:
        return None
    sr = int(sr.find("div", {"class": "u-align-center h5"}).getText())
    
    #Competitive HTML div
    comp = soup.find(
        "div", {"id": "competitive"}
    ).find(
        "section", {"class": "content-box u-max-width-container career-stats-section"}
    )

    #Extract hero data
    #if(comp == None):
    #    print(battletag)
    data = hero_data_extractor(comp)
    
    
    #Add SR attribute
    for d in data:
        d[1]["SR"] = sr
    
    """
    for d in data:
        if(d[0] == "ana"):
            sorted_keys = sorted(d[1].keys())
            for k in sorted_keys:
                print(k, d[1][k])
    """
    
    #Return data
    return data

# %% [markdown]
# ### Files

# %%
curr_battletag_index_from_scrambled_str = "../data/curr_battletag_index_from_scrambled.txt"
discovery_scrambled_str = "../data/discovery_scrambled.csv"
hero_processed_root_path = "../data/hero_processed/"
hero_raw_root_path = "../data/hero_raw/"

# %% [markdown]
# ### Existing file data

# %%
#Current battletag index
curr_battletag_index = -1
try:
    path = Path(curr_battletag_index_from_scrambled_str).resolve()
except:
    print("Current battletag index file NOT FOUND. Using current battletag index value of 0.")
    curr_battletag_index = 0
else:
    f = open(curr_battletag_index_from_scrambled_str, "r")
    curr_battletag_index = int(f.readline())
    print("Current page file FOUND. Resuming scraping from battle index {}.".format(curr_battletag_index))
    f.close()

#All battletags
battletags = []
with codecs.open(discovery_scrambled_str, "r", encoding="utf8") as f:
    for line in f:
        battletags.append(line.split(",")[1])

# %% [markdown]
# ### Hero data writer

# %%
#STored data (below) has the following structure
"""
{
    "ana": [(battletag_0, info_0_ana, original_info_0_ana), (battletag_1, info_1_ana, original_info_1_ana), ...],
    "bastion": [(battletag_0, info_0_bastion, original_info_3_bastion), (battletag_3, info_3_bastion, original_info_3_bastion), ...],,
    "d.va": [(battletag_5, info_5_d.va, original_info_5_bastion)],
    ...
}
"""
stored_data = {}
def write_hero_data():
    """
    This function writes the data in stored_data above to file. Each key
    corresponds to a hero (ana, bastion, ...), and the value is a list of
    tuples of players and their hero data for the specified hero.
    """
    #Dictionary mapping hero names to their file output
    #NOTE: This is done outside of the loops below because if
    #a dictionary error occurs (Tracer entry trying to be added with
    #Soldier76 features) we want to fail and get the KeyError before
    #writing that players info to file for other heroes.
    """
    {
        "ana": {
            path: ana_path_str
            outputs: [ana_output0, ana_output1, ...]
        },
        "bastion": {
            path: bastion_path_str
            outputs: [bastion_output0, ...]
        },
        ...
    }
    """
    #Note: This is currently not used
    #These changes were made at hero index 9771
    hero_output_map = {}
    for hero in stored_data:
        hero_output_map[hero] = {
            "paths": [],
            "outputs": ([], [])
        }
    
    #For each hero
    sorted_heroes = sorted(stored_data.keys())
    #for hero in stored_data:
    for i in range(len(sorted_heroes)):
        hero = sorted_heroes[i]
        #Don't write if no information
        if len(stored_data[hero]) == 0:
            continue
        #Presort keys, should be the same keys for each battletag (unless anomaly)
        sorted_keys_processed = sorted(stored_data[hero][0][1].keys())
        sorted_keys_processed.remove("SR")
        sorted_keys_raw = sorted(stored_data[hero][0][2].keys())
        
        #The following SHOULD be done as a 1 time external method prior to scraping. It
        #doesn't make sense from an optimization standpoint to do it inside this write
        #method which gets a lot of use. Especially since this startup only has to happen
        #once.
        #Check to see if the hero file exists. If it does not, write the keys describing
        #the entry as the top level line in the .csv
        #Paths
        path_list = [
            hero_processed_root_path,
            hero_raw_root_path
        ]
        for i in range(len(path_list)):
            path_list[i] += hero + ".csv"
        #Associated data keys
        key_list = [
            sorted_keys_processed,
            sorted_keys_raw
        ]
        #Write feature labels
        for i in range(len(path_list)):
            try:
                p = Path(path_list[i]).resolve()
            except:
                print("Current {} file DOES NOT exist. Writing feature labels.".format(hero))
                with codecs.open(path_list[i], "w", encoding="utf8") as f:
                    output = "battletag,SR"
                    for j in range(0, len(key_list[i])):
                        output += "," + key_list[i][j]
                    f.write(output + "\n")
        
        #Note the below could be done in the same enclosing loop as above. However, they're
        #separated to point out the big comment above.
        for i in range(len(path_list)):
            hero_output_map[hero]["paths"].append(path_list[i])
            #For each battletag-info pair
            for tup in stored_data[hero]:
                #First 2 line items are battletag (id) and SR (target class)
                output = tup[0] + "," + str(tup[1]["SR"])
                #Sort remaining keys
                #This should be moved to outside the tuple loop...but I'm scared of
                #some asshole with a weird/extra feature that I haven't seen yet
                #showing up and ruining the scraping. I'll do it for now but it'll
                #throw a key error if this happens.
                for j in range(0, len(key_list[i])):
                    output += "," + str(tup[i+1][key_list[i][j]])
                #Write
                hero_output_map[hero]["outputs"][i].append(output)
#                    f.write(output + "\n")
                    
    #Write to file
    for i in range(len(sorted_heroes)):
        hero = sorted_heroes[i]
        #Current hero data
        curr_map = hero_output_map[hero]
        #For each path
        for i in range(len(curr_map["paths"])):
            curr_path = curr_map["paths"][i]
            #Open file
            with codecs.open(curr_path, "a", encoding="utf8") as f:
                #Append output
                curr_out_list = curr_map["outputs"][i]
                for j in range(len(curr_out_list)):
                    f.write(curr_out_list[j] + "\n")
    
    #Empty stored data
    for hero in stored_data:
        stored_data[hero] = []

# %% [markdown]
# This just separates output from the rest of the console when it starts.

# %%
print("\n"*5)

# %% [markdown]
# ## Main
# Below is the main codeblock which runs the entire scraping/writing process. The large comment sections to start are notes on problematic battletag links.
#
# This will crash when PlayOverwatch has a poorly formatted competitive hero entry. This is in no control on our end.

# %%
#Clear stored data when restarting scrape
for hero in hero_to_hash:
    stored_data[hero] = []

#max_count = 13
#count = 0
#Notes:

#https://playoverwatch.com/en-us/career/pc/Tocom-1468
#had biotic field data for tracer on 1/28/2018 2:47pm PT
#->Removed from data set

#https://playoverwatch.com/en-us/career/pc/Persocon-2391
#had teleporter uptime features for non-symmetra characters
#on 1/31/2018 3:27pm PT
#->Removed from data set

#https://playoverwatch.com/en-us/career/pc/ohhsnap-21969
#had 50k biotic field healing done on genji on 2/22018 8:25am PT
#->Removed from data set

#https://playoverwatch.com/en-us/career/pc/Dragin-1467
#had 225 enemies frozen on lucio on 2/2/2018 9:06am PT
#->Removed from data set, but was a duplicate entry appearing early.
#Earlier entry was left in database (line 260)

#https://playoverwatch.com/en-us/career/pc/GansiHXD-11210
#81 turret kills on soldier76 on 2/2/2018 6:36pm PT
#->Removed from dataset

#https://playoverwatch.com/en-us/career/pc/SirManselot-2339
#21800 self healing on pharah on 2/5/2018 7:21am PT
#->Removed from dataset

#https://playoverwatch.com/en-us/career/pc/Gibmemore-1472
#379 seconds of teleporter uptime on widowmaker on 2/5/2018 8:02am PT
#-> Removed from dataset
#Earlier entry was left in database, removed entry at index 92086, 2nd entry at 65150

#Shuuya#2847
#biotic field healing done on lucio on 2/6/2018 5:26am PT
#-> Removed from dataset
#(Both occurences removed from dataset, they were a duplicate later beyond 90k
#aroudn 160k)

#You just need to write this battletag down because...yeah: p00pCream#1155
battletag_count = len(battletags)

#Only open up hero files every n battletags
battletags_stored = 0
write_every_n_battletags = 4
#Iterate over each battletag
print("\nResuming scraping.\n")
for i in range(curr_battletag_index, battletag_count):
    #Scrape data
    print("({}/{}) Scraping battletag {}: {}".format(
        battletags_stored,
        write_every_n_battletags,
        i,
        battletags[i]
    ))
    start_time = time.time()
    recent_data_list = scrape_data_for_battletag(battletags[i])
    print("Took {}s".format(time.time() - start_time))
    
    #In event where a battletag was scraped and known to have an SR, but
    #because of OverwatchTracker or PlayOverwatch misinformation,
    #PlayOverwatch does not have an SR for the player at this time.
    if recent_data_list == None:
        print("No SR...moving on.")
        continue
    
    #Recent_data_list of form [(hero_0, map_hero_0), (hero_1, map_hero_1), ...]
    for tup in recent_data_list:
        stored_data[tup[0]].append((battletags[i], tup[1], tup[2]))
    battletags_stored += 1
    
    #Store data if necessary
    if battletags_stored == write_every_n_battletags:
        print("Writing to file.")
        write_hero_data()
        #Update current battletag index
        f = open(curr_battletag_index_from_scrambled_str, "w")
        curr_battletag_index = i+1
        f.write(str(curr_battletag_index))
        f.close()
        
        #Reset battletags stored
        battletags_stored = 0
        
        print("Data stored.")
        print("\n-------------------\n")
    
    #count += 1
    #if count == max_count:
    #    break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-d33fd3af874f> in <module>()
#      73     if battletags_stored == write_every_n_battletags:
#      74         print("Writing to file.")
# ---> 75         write_hero_data()
#      76         #Update current battletag index
#      77         f = open(curr_battletag_index_from_scrambled_str, "w")
#
# <ipython-input-16-12bb02e5e254> in write_hero_data()
#      99                 #throw a key error if this happens.
#     100                 for j in range(0, len(key_list[i])):
# --> 101                     output += "," + str(tup[i+1][key_list[i][j]])
#     102                 #Write
#     103                 hero_output_map[hero]["outputs"][i].append(output)
#
# KeyError: u'biotic_field_healing_done_per_life'

# %%
stored_data
# Out:
# {'ana': [(u'Microcity#1653',
#    {'SR': 2830,
#     u'all_damage_done_per_life': 640.5901639344262,
#     u'all_damage_done_per_second': 10.854444444444445,
#     'average_life': 59.01639344262295,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     'biotic_grenade_kills_per_life': 0.0,
#     'biotic_grenade_kills_per_second': 0.0,
#     'cards_per_game': 0.0,
#     'critical_hit_accuracy': 0,
#     'critical_hits_per_life': 0.0,
#     'critical_hits_per_second': 0.0,
#     u'deaths': 60,
#     u'defensive_assists_per_life': 1.2459016393442623,
#     u'defensive_assists_per_second': 0.021111111111111112,
#     u'eliminations_per_life': 1.5737704918032787,
#     u'eliminations_per_second': 0.02666666666666667,
#     u'enemies_slept_per_life': 1.0819672131147542,
#     u'enemies_slept_per_second': 0.018333333333333333,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.40625,
#     u'final_blows_per_life': 0.639344262295082,
#     u'final_blows_per_second': 0.010833333333333334,
#     'games_lost': 2,
#     u'games_played': 6,
#     'games_tied': 0,
#     u'games_won': 5,
#     'grenade_kills_to_eliminations_ratio': 0.0,
#     u'healing_done_per_life': 919.1311475409836,
#     u'healing_done_per_second': 15.574166666666667,
#     'healing_to_damage_ratio': 1.434819326440782,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'medals_-_bronze_per_game': 0.8333333333333334,
#     u'medals_-_gold_per_game': 0.6666666666666666,
#     u'medals_-_silver_per_game': 0.6666666666666666,
#     u'medals_per_game': 2.1666666666666665,
#     u'melee_final_blows_per_life': 0.01639344262295082,
#     u'melee_final_blows_per_second': 0.0002777777777777778,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'nano_assists_to_applied_ratio': 0.9354838709677419,
#     u'nano_boost_assists_per_life': 0.47540983606557374,
#     u'nano_boost_assists_per_second': 0.008055555555555555,
#     u'nano_boosts_applied_per_life': 0.5081967213114754,
#     u'nano_boosts_applied_per_second': 0.008611111111111111,
#     'objective_kills_per_elimination': 0.3645833333333333,
#     u'objective_kills_per_life': 0.5737704918032787,
#     u'objective_kills_per_second': 0.009722222222222222,
#     u'objective_time_seconds_per_life': 8.62295081967213,
#     u'objective_time_seconds_per_second': 0.1461111111111111,
#     u'offensive_assists_per_life': 1.180327868852459,
#     u'offensive_assists_per_second': 0.02,
#     'quick_melee_accuracy': 0,
#     u'scoped_accuracy': 0.57,
#     u'self_healing_per_life': 76.06557377049181,
#     u'self_healing_per_second': 1.288888888888889,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.041666666666666664,
#     u'solo_kills_per_life': 0.06557377049180328,
#     u'solo_kills_per_second': 0.0011111111111111111,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 3600,
#     u'time_spent_on_fire_seconds_per_life': 10.311475409836065,
#     u'time_spent_on_fire_seconds_per_second': 0.17472222222222222,
#     u'turrets_destroyed_per_life': 0.03278688524590164,
#     u'turrets_destroyed_per_second': 0.0005555555555555556,
#     u'unscoped_accuracy': 1,
#     u'weapon_accuracy': 0.15,
#     u'win_percentage': 0.72},
#    {u'all_damage_done': 39076,
#     'barrier_damage_done': 0,
#     'biotic_grenade_kills': 0,
#     'cards': 0,
#     'critical_hit_accuracy': 0,
#     'critical_hits': 0,
#     u'deaths': 60,
#     u'defensive_assists': 76,
#     u'eliminations': 96,
#     u'enemies_slept': 66,
#     'environmental_kills': 0,
#     u'final_blows': 39,
#     'games_lost': 2,
#     u'games_played': 6,
#     'games_tied': 0,
#     u'games_won': 5,
#     u'healing_done': 56067,
#     'hero_damage_done': 0,
#     u'medals': 13,
#     u'medals_-_bronze': 5,
#     u'medals_-_gold': 4,
#     u'medals_-_silver': 4,
#     u'melee_final_blows': 1,
#     'multikills': 0,
#     u'nano_boost_assists': 29,
#     u'nano_boosts_applied': 31,
#     u'objective_kills': 35,
#     u'objective_time_seconds': 526,
#     u'offensive_assists': 72,
#     'quick_melee_accuracy': 0,
#     u'scoped_accuracy': 0.57,
#     u'self_healing': 4640,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 4,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 3600,
#     u'time_spent_on_fire_seconds': 629,
#     u'turrets_destroyed': 2,
#     u'unscoped_accuracy': 1,
#     u'weapon_accuracy': 0.15,
#     u'win_percentage': 0.72}),
#   (u'FINALBOSS#12814',
#    {'SR': 2668,
#     u'all_damage_done_per_life': 407.6666666666667,
#     u'all_damage_done_per_second': 5.662037037037037,
#     'average_life': 72.0,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     'biotic_grenade_kills_per_life': 0.0,
#     'biotic_grenade_kills_per_second': 0.0,
#     u'cards_per_game': 0.5,
#     'critical_hit_accuracy': 0,
#     'critical_hits_per_life': 0.0,
#     'critical_hits_per_second': 0.0,
#     u'deaths': 14,
#     u'defensive_assists_per_life': 1.0,
#     u'defensive_assists_per_second': 0.013888888888888888,
#     u'eliminations_per_life': 0.8666666666666667,
#     u'eliminations_per_second': 0.012037037037037037,
#     u'enemies_slept_per_life': 0.6,
#     u'enemies_slept_per_second': 0.008333333333333333,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.15384615384615385,
#     u'final_blows_per_life': 0.13333333333333333,
#     u'final_blows_per_second': 0.001851851851851852,
#     'games_lost': 1,
#     u'games_played': 2,
#     'games_tied': 0,
#     u'games_won': 1,
#     'grenade_kills_to_eliminations_ratio': 0.0,
#     u'healing_done_per_life': 919.2,
#     u'healing_done_per_second': 12.766666666666667,
#     'healing_to_damage_ratio': 2.2547833197056417,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     'medals_-_bronze_per_game': 0.0,
#     u'medals_-_gold_per_game': 1.0,
#     u'medals_-_silver_per_game': 1.0,
#     u'medals_per_game': 1.5,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'nano_assists_to_applied_ratio': 0.6666666666666666,
#     u'nano_boost_assists_per_life': 0.26666666666666666,
#     u'nano_boost_assists_per_second': 0.003703703703703704,
#     u'nano_boosts_applied_per_life': 0.4,
#     u'nano_boosts_applied_per_second': 0.005555555555555556,
#     'objective_kills_per_elimination': 0.5384615384615384,
#     u'objective_kills_per_life': 0.4666666666666667,
#     u'objective_kills_per_second': 0.006481481481481481,
#     u'objective_time_seconds_per_life': 5.666666666666667,
#     u'objective_time_seconds_per_second': 0.0787037037037037,
#     u'offensive_assists_per_life': 0.6666666666666666,
#     u'offensive_assists_per_second': 0.009259259259259259,
#     'quick_melee_accuracy': 0,
#     u'scoped_accuracy': 0.62,
#     u'self_healing_per_life': 49.06666666666667,
#     u'self_healing_per_second': 0.6814814814814815,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.0,
#     'solo_kills_per_life': 0.0,
#     'solo_kills_per_second': 0.0,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 1080,
#     u'time_spent_on_fire_seconds_per_life': 1.2,
#     u'time_spent_on_fire_seconds_per_second': 0.016666666666666666,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'unscoped_accuracy': 1,
#     u'weapon_accuracy': 0.11,
#     u'win_percentage': 0.46},
#    {u'all_damage_done': 6115,
#     'barrier_damage_done': 0,
#     'biotic_grenade_kills': 0,
#     u'cards': 1,
#     'critical_hit_accuracy': 0,
#     'critical_hits': 0,
#     u'deaths': 14,
#     u'defensive_assists': 15,
#     u'eliminations': 13,
#     u'enemies_slept': 9,
#     'environmental_kills': 0,
#     u'final_blows': 2,
#     'games_lost': 1,
#     u'games_played': 2,
#     'games_tied': 0,
#     u'games_won': 1,
#     u'healing_done': 13788,
#     'hero_damage_done': 0,
#     u'medals': 3,
#     'medals_-_bronze': 0,
#     u'medals_-_gold': 2,
#     u'medals_-_silver': 2,
#     'melee_final_blows': 0,
#     'multikills': 0,
#     u'nano_boost_assists': 4,
#     u'nano_boosts_applied': 6,
#     u'objective_kills': 7,
#     u'objective_time_seconds': 85,
#     u'offensive_assists': 10,
#     'quick_melee_accuracy': 0,
#     u'scoped_accuracy': 0.62,
#     u'self_healing': 736,
#     'shield_generators_destroyed': 0,
#     'solo_kills': 0,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 1080,
#     u'time_spent_on_fire_seconds': 18,
#     'turrets_destroyed': 0,
#     u'unscoped_accuracy': 1,
#     u'weapon_accuracy': 0.11,
#     u'win_percentage': 0.46})],
#  'bastion': [(u'Shuuya#2847',
#    {'SR': 61,
#     u'all_damage_done_per_life': 1454.25,
#     u'all_damage_done_per_second': 25.513157894736842,
#     'average_life': 57.0,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     u'cards_per_game': 1.0,
#     u'critical_hit_accuracy': 0.06,
#     u'critical_hits_per_life': 5.85,
#     u'critical_hits_per_second': 0.10263157894736842,
#     u'deaths': 19,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 2.65,
#     u'eliminations_per_second': 0.04649122807017544,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.660377358490566,
#     u'final_blows_per_life': 1.75,
#     u'final_blows_per_second': 0.03070175438596491,
#     'games_lost': 0,
#     u'games_played': 2,
#     'games_tied': 0,
#     u'games_won': 1,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'medals_-_bronze_per_game': 0.5,
#     u'medals_-_gold_per_game': 1.5,
#     u'medals_-_silver_per_game': 0.5,
#     u'medals_per_game': 3.0,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     u'multikills_per_life': 0.05,
#     u'multikills_per_second': 0.0008771929824561404,
#     'objective_kills_per_elimination': 0.5660377358490566,
#     u'objective_kills_per_life': 1.5,
#     u'objective_kills_per_second': 0.02631578947368421,
#     u'objective_time_seconds_per_life': 2.2,
#     u'objective_time_seconds_per_second': 0.03859649122807018,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     'quick_melee_accuracy': 0,
#     u'recon_kills_per_life': 0.65,
#     u'recon_kills_per_second': 0.011403508771929825,
#     'recon_kills_to_eliminations_ratio': 0.24528301886792453,
#     u'self_healing_per_life': 118.55,
#     u'self_healing_per_second': 2.079824561403509,
#     u'sentry_kills_per_life': 1.75,
#     u'sentry_kills_per_second': 0.03070175438596491,
#     'sentry_kills_to_eliminations_ratio': 0.660377358490566,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.07547169811320754,
#     u'solo_kills_per_life': 0.2,
#     u'solo_kills_per_second': 0.0035087719298245615,
#     u'tank_kills_per_life': 0.25,
#     u'tank_kills_per_second': 0.0043859649122807015,
#     'tank_kills_to_eliminations_ratio': 0.09433962264150944,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 1140,
#     u'time_spent_on_fire_seconds_per_life': 16.7,
#     u'time_spent_on_fire_seconds_per_second': 0.2929824561403509,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'weapon_accuracy': 0.27,
#     u'win_percentage': 0.74},
#    {u'all_damage_done': 29085,
#     'barrier_damage_done': 0,
#     u'cards': 2,
#     u'critical_hit_accuracy': 0.06,
#     u'critical_hits': 117,
#     u'deaths': 19,
#     'defensive_assists': 0,
#     u'eliminations': 53,
#     'environmental_kills': 0,
#     u'final_blows': 35,
#     'games_lost': 0,
#     u'games_played': 2,
#     'games_tied': 0,
#     u'games_won': 1,
#     'healing_done': 0,
#     'hero_damage_done': 0,
#     u'medals': 6,
#     u'medals_-_bronze': 1,
#     u'medals_-_gold': 3,
#     u'medals_-_silver': 1,
#     'melee_final_blows': 0,
#     u'multikills': 1,
#     u'objective_kills': 30,
#     u'objective_time_seconds': 44,
#     'offensive_assists': 0,
#     'quick_melee_accuracy': 0,
#     u'recon_kills': 13,
#     u'self_healing': 2371,
#     u'sentry_kills': 35,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 4,
#     u'tank_kills': 5,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 1140,
#     u'time_spent_on_fire_seconds': 334,
#     'turrets_destroyed': 0,
#     u'weapon_accuracy': 0.27,
#     u'win_percentage': 0.74}),
#   (u'Microcity#1653',
#    {'SR': 2830,
#     u'all_damage_done_per_life': 1350.0,
#     u'all_damage_done_per_second': 56.25,
#     'average_life': 24.0,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     'cards_per_game': 0.0,
#     u'critical_hit_accuracy': 0.0,
#     u'critical_hits_per_life': 0.2,
#     u'critical_hits_per_second': 0.008333333333333333,
#     u'deaths': 4,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 0.8,
#     u'eliminations_per_second': 0.03333333333333333,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.5,
#     u'final_blows_per_life': 0.4,
#     u'final_blows_per_second': 0.016666666666666666,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     'games_won': 0,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'medals_-_bronze_per_game': 0.0,
#     u'medals_-_gold_per_game': 0.0,
#     u'medals_-_silver_per_game': 0.0,
#     u'medals_per_game': 1.0,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.25,
#     u'objective_kills_per_life': 0.2,
#     u'objective_kills_per_second': 0.008333333333333333,
#     u'objective_time_seconds_per_life': 4.0,
#     u'objective_time_seconds_per_second': 0.16666666666666666,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     'quick_melee_accuracy': 0,
#     u'recon_kills_per_life': 0.2,
#     u'recon_kills_per_second': 0.008333333333333333,
#     'recon_kills_to_eliminations_ratio': 0.25,
#     u'self_healing_per_life': 76.6,
#     u'self_healing_per_second': 3.191666666666667,
#     u'sentry_kills_per_life': 0.4,
#     u'sentry_kills_per_second': 0.016666666666666666,
#     'sentry_kills_to_eliminations_ratio': 0.5,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.25,
#     u'solo_kills_per_life': 0.2,
#     u'solo_kills_per_second': 0.008333333333333333,
#     u'tank_kills_per_life': 0.2,
#     u'tank_kills_per_second': 0.008333333333333333,
#     'tank_kills_to_eliminations_ratio': 0.25,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 120,
#     'time_spent_on_fire_seconds_per_life': 0.0,
#     'time_spent_on_fire_seconds_per_second': 0.0,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'weapon_accuracy': 0.33,
#     'win_percentage': 0},
#    {u'all_damage_done': 6750,
#     'barrier_damage_done': 0,
#     'cards': 0,
#     u'critical_hit_accuracy': 0.0,
#     u'critical_hits': 1,
#     u'deaths': 4,
#     'defensive_assists': 0,
#     u'eliminations': 4,
#     'environmental_kills': 0,
#     u'final_blows': 2,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     'games_won': 0,
#     'healing_done': 0,
#     'hero_damage_done': 0,
#     u'medals': 1,
#     u'medals_-_bronze': 0,
#     u'medals_-_gold': 0,
#     u'medals_-_silver': 0,
#     'melee_final_blows': 0,
#     'multikills': 0,
#     u'objective_kills': 1,
#     u'objective_time_seconds': 20,
#     'offensive_assists': 0,
#     'quick_melee_accuracy': 0,
#     u'recon_kills': 1,
#     u'self_healing': 383,
#     u'sentry_kills': 2,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 1,
#     u'tank_kills': 1,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 120,
#     'time_spent_on_fire_seconds': 0,
#     'turrets_destroyed': 0,
#     u'weapon_accuracy': 0.33,
#     'win_percentage': 0}),
#   (u'Mushmak#1423',
#    {'SR': 3982,
#     u'all_damage_done_per_life': 743.625,
#     u'all_damage_done_per_second': 16.525,
#     'average_life': 45.0,
#     u'barrier_damage_done_per_life': 166.625,
#     u'barrier_damage_done_per_second': 3.702777777777778,
#     'cards_per_game': 0.0,
#     u'critical_hit_accuracy': 0.01,
#     u'critical_hits_per_life': 0.75,
#     u'critical_hits_per_second': 0.016666666666666666,
#     u'deaths': 7,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 1.75,
#     u'eliminations_per_second': 0.03888888888888889,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.42857142857142855,
#     u'final_blows_per_life': 0.75,
#     u'final_blows_per_second': 0.016666666666666666,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     'games_won': 0,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     u'hero_damage_done_per_life': 535.875,
#     u'hero_damage_done_per_second': 11.908333333333333,
#     'hero_to_barrier_damage_ratio': 3.216054013503376,
#     u'medals_-_bronze_per_game': 0.0,
#     'medals_-_gold_per_game': 0.0,
#     u'medals_-_silver_per_game': 1.0,
#     u'medals_per_game': 1.0,
#     u'melee_final_blows_per_life': 0.125,
#     u'melee_final_blows_per_second': 0.002777777777777778,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.5,
#     u'objective_kills_per_life': 0.875,
#     u'objective_kills_per_second': 0.019444444444444445,
#     u'objective_time_seconds_per_life': 17.25,
#     u'objective_time_seconds_per_second': 0.38333333333333336,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     u'quick_melee_accuracy': 0,
#     u'recon_kills_per_life': 1.125,
#     u'recon_kills_per_second': 0.025,
#     'recon_kills_to_eliminations_ratio': 0.6428571428571429,
#     u'self_healing_per_life': 79.25,
#     u'self_healing_per_second': 1.761111111111111,
#     u'sentry_kills_per_life': 0.625,
#     u'sentry_kills_per_second': 0.013888888888888888,
#     'sentry_kills_to_eliminations_ratio': 0.35714285714285715,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.0,
#     'solo_kills_per_life': 0.0,
#     'solo_kills_per_second': 0.0,
#     'tank_kills_per_life': 0.0,
#     'tank_kills_per_second': 0.0,
#     'tank_kills_to_eliminations_ratio': 0.0,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 360,
#     u'time_spent_on_fire_seconds_per_life': 5.25,
#     u'time_spent_on_fire_seconds_per_second': 0.11666666666666667,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'weapon_accuracy': 0.22,
#     'win_percentage': 0},
#    {u'all_damage_done': 5949,
#     u'barrier_damage_done': 1333,
#     'cards': 0,
#     u'critical_hit_accuracy': 0.01,
#     u'critical_hits': 6,
#     u'deaths': 7,
#     'defensive_assists': 0,
#     u'eliminations': 14,
#     'environmental_kills': 0,
#     u'final_blows': 6,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     'games_won': 0,
#     'healing_done': 0,
#     u'hero_damage_done': 4287,
#     u'medals': 1,
#     u'medals_-_bronze': 0,
#     'medals_-_gold': 0,
#     u'medals_-_silver': 1,
#     u'melee_final_blows': 1,
#     'multikills': 0,
#     u'objective_kills': 7,
#     u'objective_time_seconds': 138,
#     'offensive_assists': 0,
#     u'quick_melee_accuracy': 0,
#     u'recon_kills': 9,
#     u'self_healing': 634,
#     u'sentry_kills': 5,
#     'shield_generators_destroyed': 0,
#     'solo_kills': 0,
#     'tank_kills': 0,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 360,
#     u'time_spent_on_fire_seconds': 42,
#     'turrets_destroyed': 0,
#     u'weapon_accuracy': 0.22,
#     'win_percentage': 0})],
#  'd.va': [(u'Microcity#1653',
#    {'SR': 2830,
#     u'all_damage_done_per_life': 1936.0,
#     u'all_damage_done_per_second': 18.822222222222223,
#     'average_life': 102.85714285714286,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     u'cards_per_game': 0.25,
#     u'critical_hit_accuracy': 0.07,
#     u'critical_hits_per_life': 56.371428571428574,
#     u'critical_hits_per_second': 0.5480555555555555,
#     u'damage_blocked_per_life': 1576.8,
#     u'damage_blocked_per_second': 15.33,
#     'damage_blocked_to_output_ratio': 0.8144628099173554,
#     u'deaths': 34,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 3.914285714285714,
#     u'eliminations_per_second': 0.03805555555555556,
#     u'environmental_kills_per_life': 0.05714285714285714,
#     u'environmental_kills_per_second': 0.0005555555555555556,
#     'environmental_kills_to_eliminations_ratio': 0.014598540145985401,
#     'final_blows_per_elimination': 0.45255474452554745,
#     u'final_blows_per_life': 1.7714285714285714,
#     u'final_blows_per_second': 0.017222222222222222,
#     'games_lost': 1,
#     u'games_played': 4,
#     u'games_tied': 0,
#     u'games_won': 2,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'mech_deaths_per_life': 1.4,
#     u'mech_deaths_per_second': 0.01361111111111111,
#     'mech_deaths_to_deaths_ratio': 1.4411764705882353,
#     u'mechs_called_per_life': 0.9714285714285714,
#     u'mechs_called_per_second': 0.009444444444444445,
#     u'medals_-_bronze_per_game': 1.0,
#     u'medals_-_gold_per_game': 1.5,
#     u'medals_-_silver_per_game': 1.25,
#     u'medals_per_game': 3.75,
#     u'melee_final_blows_per_life': 0.02857142857142857,
#     u'melee_final_blows_per_second': 0.0002777777777777778,
#     u'multikills_per_life': 0.08571428571428572,
#     u'multikills_per_second': 0.0008333333333333334,
#     'objective_kills_per_elimination': 0.5255474452554745,
#     u'objective_kills_per_life': 2.057142857142857,
#     u'objective_kills_per_second': 0.02,
#     u'objective_time_seconds_per_life': 20.2,
#     u'objective_time_seconds_per_second': 0.1963888888888889,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     'quick_melee_accuracy': 0,
#     u'self-destruct_kills_per_life': 0.34285714285714286,
#     u'self-destruct_kills_per_second': 0.0033333333333333335,
#     'self-destruct_kills_to_eliminations_ratio': 0.08759124087591241,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.051094890510948905,
#     u'solo_kills_per_life': 0.2,
#     u'solo_kills_per_second': 0.0019444444444444444,
#     u'teleporter_pads_destroyed_per_life': 0.05714285714285714,
#     u'teleporter_pads_destroyed_per_second': 0.0005555555555555556,
#     u'time_played_seconds': 3600,
#     u'time_spent_on_fire_seconds_per_life': 14.885714285714286,
#     u'time_spent_on_fire_seconds_per_second': 0.14472222222222222,
#     u'turrets_destroyed_per_life': 0.14285714285714285,
#     u'turrets_destroyed_per_second': 0.001388888888888889,
#     u'weapon_accuracy': 0.36,
#     u'win_percentage': 0.56},
#    {u'all_damage_done': 67760,
#     'barrier_damage_done': 0,
#     u'cards': 1,
#     u'critical_hit_accuracy': 0.07,
#     u'critical_hits': 1973,
#     u'damage_blocked': 55188,
#     u'deaths': 34,
#     'defensive_assists': 0,
#     u'eliminations': 137,
#     u'environmental_kills': 2,
#     u'final_blows': 62,
#     'games_lost': 1,
#     u'games_played': 4,
#     u'games_tied': 0,
#     u'games_won': 2,
#     'healing_done': 0,
#     'hero_damage_done': 0,
#     u'mech_deaths': 49,
#     u'mechs_called': 34,
#     u'medals': 15,
#     u'medals_-_bronze': 4,
#     u'medals_-_gold': 6,
#     u'medals_-_silver': 5,
#     u'melee_final_blows': 1,
#     u'multikills': 3,
#     u'objective_kills': 72,
#     u'objective_time_seconds': 707,
#     'offensive_assists': 0,
#     'quick_melee_accuracy': 0,
#     u'self-destruct_kills': 12,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 7,
#     u'teleporter_pads_destroyed': 2,
#     u'time_played_seconds': 3600,
#     u'time_spent_on_fire_seconds': 521,
#     u'turrets_destroyed': 5,
#     u'weapon_accuracy': 0.36,
#     u'win_percentage': 0.56}),
#   (u'Mushmak#1423',
#    {'SR': 3982,
#     u'all_damage_done_per_life': 1520.3333333333333,
#     u'all_damage_done_per_second': 30.406666666666666,
#     'average_life': 50.0,
#     u'barrier_damage_done_per_life': 498.4583333333333,
#     u'barrier_damage_done_per_second': 9.969166666666666,
#     u'cards_per_game': 0.3333333333333333,
#     u'critical_hit_accuracy': 0.07,
#     u'critical_hits_per_life': 29.38888888888889,
#     u'critical_hits_per_second': 0.5877777777777777,
#     u'damage_blocked_per_life': 783.4027777777778,
#     u'damage_blocked_per_second': 15.668055555555556,
#     'damage_blocked_to_output_ratio': 0.515283563546006,
#     u'deaths': 71,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 3.6944444444444446,
#     u'eliminations_per_second': 0.07388888888888889,
#     u'environmental_kills_per_life': 0.013888888888888888,
#     u'environmental_kills_per_second': 0.0002777777777777778,
#     'environmental_kills_to_eliminations_ratio': 0.0037593984962406013,
#     'final_blows_per_elimination': 0.31203007518796994,
#     u'final_blows_per_life': 1.1527777777777777,
#     u'final_blows_per_second': 0.023055555555555555,
#     'games_lost': 3,
#     u'games_played': 6,
#     'games_tied': 0,
#     u'games_won': 4,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     u'hero_damage_done_per_life': 1004.1111111111111,
#     u'hero_damage_done_per_second': 20.08222222222222,
#     'hero_to_barrier_damage_ratio': 2.014433391847084,
#     u'mech_deaths_per_life': 1.1805555555555556,
#     u'mech_deaths_per_second': 0.02361111111111111,
#     'mech_deaths_to_deaths_ratio': 1.1971830985915493,
#     u'mechs_called_per_life': 0.7777777777777778,
#     u'mechs_called_per_second': 0.015555555555555555,
#     u'medals_-_bronze_per_game': 1.8333333333333333,
#     u'medals_-_gold_per_game': 1.5,
#     u'medals_-_silver_per_game': 0.6666666666666666,
#     u'medals_per_game': 4.166666666666667,
#     u'melee_final_blows_per_life': 0.08333333333333333,
#     u'melee_final_blows_per_second': 0.0016666666666666668,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.40977443609022557,
#     u'objective_kills_per_life': 1.5138888888888888,
#     u'objective_kills_per_second': 0.03027777777777778,
#     u'objective_time_seconds_per_life': 15.083333333333334,
#     u'objective_time_seconds_per_second': 0.3016666666666667,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     u'quick_melee_accuracy': 0,
#     u'self-destruct_kills_per_life': 0.25,
#     u'self-destruct_kills_per_second': 0.005,
#     'self-destruct_kills_to_eliminations_ratio': 0.06766917293233082,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.02631578947368421,
#     u'solo_kills_per_life': 0.09722222222222222,
#     u'solo_kills_per_second': 0.0019444444444444444,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 3600,
#     u'time_spent_on_fire_seconds_per_life': 13.375,
#     u'time_spent_on_fire_seconds_per_second': 0.2675,
#     u'turrets_destroyed_per_life': 0.027777777777777776,
#     u'turrets_destroyed_per_second': 0.0005555555555555556,
#     u'weapon_accuracy': 0.25,
#     u'win_percentage': 0.56},
#    {u'all_damage_done': 109464,
#     u'barrier_damage_done': 35889,
#     u'cards': 2,
#     u'critical_hit_accuracy': 0.07,
#     u'critical_hits': 2116,
#     u'damage_blocked': 56405,
#     u'deaths': 71,
#     'defensive_assists': 0,
#     u'eliminations': 266,
#     u'environmental_kills': 1,
#     u'final_blows': 83,
#     'games_lost': 3,
#     u'games_played': 6,
#     'games_tied': 0,
#     u'games_won': 4,
#     'healing_done': 0,
#     u'hero_damage_done': 72296,
#     u'mech_deaths': 85,
#     u'mechs_called': 56,
#     u'medals': 25,
#     u'medals_-_bronze': 11,
#     u'medals_-_gold': 9,
#     u'medals_-_silver': 4,
#     u'melee_final_blows': 6,
#     'multikills': 0,
#     u'objective_kills': 109,
#     u'objective_time_seconds': 1086,
#     'offensive_assists': 0,
#     u'quick_melee_accuracy': 0,
#     u'self-destruct_kills': 18,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 7,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 3600,
#     u'time_spent_on_fire_seconds': 963,
#     u'turrets_destroyed': 2,
#     u'weapon_accuracy': 0.25,
#     u'win_percentage': 0.56}),
#   (u'FINALBOSS#12814',
#    {'SR': 2668,
#     u'all_damage_done_per_life': 2637.5172413793102,
#     u'all_damage_done_per_second': 21.979310344827585,
#     'average_life': 120.0,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     u'cards_per_game': 0.25,
#     u'critical_hit_accuracy': 0.06,
#     u'critical_hits_per_life': 71.79310344827586,
#     u'critical_hits_per_second': 0.5982758620689655,
#     u'damage_blocked_per_life': 1142.7931034482758,
#     u'damage_blocked_per_second': 9.523275862068965,
#     'damage_blocked_to_output_ratio': 0.43328365233762156,
#     u'deaths': 28,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 4.9655172413793105,
#     u'eliminations_per_second': 0.041379310344827586,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'environmental_kills_to_eliminations_ratio': 0.0,
#     'final_blows_per_elimination': 0.3402777777777778,
#     u'final_blows_per_life': 1.6896551724137931,
#     u'final_blows_per_second': 0.014080459770114942,
#     'games_lost': 3,
#     u'games_played': 4,
#     'games_tied': 0,
#     u'games_won': 1,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'mech_deaths_per_life': 1.2758620689655173,
#     u'mech_deaths_per_second': 0.010632183908045977,
#     'mech_deaths_to_deaths_ratio': 1.3214285714285714,
#     u'mechs_called_per_life': 0.9655172413793104,
#     u'mechs_called_per_second': 0.008045977011494253,
#     u'medals_-_bronze_per_game': 0.75,
#     u'medals_-_gold_per_game': 1.5,
#     u'medals_-_silver_per_game': 1.0,
#     u'medals_per_game': 3.5,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     u'multikills_per_life': 0.06896551724137931,
#     u'multikills_per_second': 0.0005747126436781609,
#     'objective_kills_per_elimination': 0.3680555555555556,
#     u'objective_kills_per_life': 1.8275862068965518,
#     u'objective_kills_per_second': 0.015229885057471264,
#     u'objective_time_seconds_per_life': 20.551724137931036,
#     u'objective_time_seconds_per_second': 0.17126436781609194,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     'quick_melee_accuracy': 0,
#     u'self-destruct_kills_per_life': 0.3103448275862069,
#     u'self-destruct_kills_per_second': 0.002586206896551724,
#     'self-destruct_kills_to_eliminations_ratio': 0.0625,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.034722222222222224,
#     u'solo_kills_per_life': 0.1724137931034483,
#     u'solo_kills_per_second': 0.0014367816091954023,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 3480,
#     u'time_spent_on_fire_seconds_per_life': 7.448275862068965,
#     u'time_spent_on_fire_seconds_per_second': 0.06206896551724138,
#     u'turrets_destroyed_per_life': 0.034482758620689655,
#     u'turrets_destroyed_per_second': 0.00028735632183908046,
#     u'weapon_accuracy': 0.31,
#     u'win_percentage': 0.27},
#    {u'all_damage_done': 76488,
#     'barrier_damage_done': 0,
#     u'cards': 1,
#     u'critical_hit_accuracy': 0.06,
#     u'critical_hits': 2082,
#     u'damage_blocked': 33141,
#     u'deaths': 28,
#     'defensive_assists': 0,
#     u'eliminations': 144,
#     'environmental_kills': 0,
#     u'final_blows': 49,
#     'games_lost': 3,
#     u'games_played': 4,
#     'games_tied': 0,
#     u'games_won': 1,
#     'healing_done': 0,
#     'hero_damage_done': 0,
#     u'mech_deaths': 37,
#     u'mechs_called': 28,
#     u'medals': 14,
#     u'medals_-_bronze': 3,
#     u'medals_-_gold': 6,
#     u'medals_-_silver': 4,
#     'melee_final_blows': 0,
#     u'multikills': 2,
#     u'objective_kills': 53,
#     u'objective_time_seconds': 596,
#     'offensive_assists': 0,
#     'quick_melee_accuracy': 0,
#     u'self-destruct_kills': 9,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 5,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 3480,
#     u'time_spent_on_fire_seconds': 216,
#     u'turrets_destroyed': 1,
#     u'weapon_accuracy': 0.31,
#     u'win_percentage': 0.27})],
#  'doomfist': [(u'Mushmak#1423',
#    {'SR': 3982,
#     u'ability_damage_done_per_life': 173.9475,
#     u'ability_damage_done_per_second': 5.7982499999999995,
#     u'all_damage_done_per_life': 426.25,
#     u'all_damage_done_per_second': 14.208333333333334,
#     'average_life': 30.0,
#     u'barrier_damage_done_per_life': 103.0,
#     u'barrier_damage_done_per_second': 3.433333333333333,
#     'cards_per_game': 0.0,
#     'critical_hit_accuracy': 0,
#     'critical_hits_per_life': 0.0,
#     'critical_hits_per_second': 0.0,
#     u'deaths': 3,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 1.25,
#     u'eliminations_per_second': 0.041666666666666664,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'environmental_kills_to_eliminations_ratio': 0.0,
#     'final_blows_per_elimination': 0.8,
#     u'final_blows_per_life': 1.0,
#     u'final_blows_per_second': 0.03333333333333333,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     'games_won': 0,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     u'hero_damage_done_per_life': 323.25,
#     u'hero_damage_done_per_second': 10.775,
#     'hero_to_barrier_damage_ratio': 3.1383495145631066,
#     'medals_-_bronze_per_game': 0.0,
#     'medals_-_gold_per_game': 0.0,
#     u'medals_-_silver_per_game': 1.0,
#     u'medals_per_game': 1.0,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     'meteor_strike_kills_per_life': 0.0,
#     'meteor_strike_kills_per_second': 0.0,
#     'meteor_strike_kills_to_eliminations_ratio': 0.0,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.8,
#     u'objective_kills_per_life': 1.0,
#     u'objective_kills_per_second': 0.03333333333333333,
#     u'objective_time_seconds_per_life': 6.0,
#     u'objective_time_seconds_per_second': 0.2,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     u'quick_melee_accuracy': 1,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     u'shields_created_per_life': 56.25,
#     u'shields_created_per_second': 1.875,
#     'solo_kills_per_elimination': 0.0,
#     'solo_kills_per_life': 0.0,
#     'solo_kills_per_second': 0.0,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 120,
#     'time_spent_on_fire_seconds_per_life': 0.0,
#     'time_spent_on_fire_seconds_per_second': 0.0,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'weapon_accuracy': 0.55,
#     'win_percentage': 0},
#    {u'ability_damage_done': 695.79,
#     u'all_damage_done': 1705,
#     u'barrier_damage_done': 412,
#     'cards': 0,
#     'critical_hit_accuracy': 0,
#     'critical_hits': 0,
#     u'deaths': 3,
#     'defensive_assists': 0,
#     u'eliminations': 5,
#     'environmental_kills': 0,
#     u'final_blows': 4,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     'games_won': 0,
#     'healing_done': 0,
#     u'hero_damage_done': 1293,
#     u'medals': 1,
#     'medals_-_bronze': 0,
#     'medals_-_gold': 0,
#     u'medals_-_silver': 1,
#     'melee_final_blows': 0,
#     'meteor_strike_kills': 0,
#     'multikills': 0,
#     u'objective_kills': 4,
#     u'objective_time_seconds': 24,
#     'offensive_assists': 0,
#     u'quick_melee_accuracy': 1,
#     'shield_generators_destroyed': 0,
#     u'shields_created': 225,
#     'solo_kills': 0,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 120,
#     'time_spent_on_fire_seconds': 0,
#     'turrets_destroyed': 0,
#     u'weapon_accuracy': 0.55,
#     'win_percentage': 0})],
#  'genji': [(u'Shuuya#2847',
#    {'SR': 61,
#     u'all_damage_done_per_life': 451.6,
#     u'all_damage_done_per_second': 12.544444444444444,
#     'average_life': 36.0,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     'cards_per_game': 0.0,
#     u'critical_hit_accuracy': 0.05,
#     u'critical_hits_per_life': 0.8,
#     u'critical_hits_per_second': 0.022222222222222223,
#     u'damage_reflected_per_life': 11.2,
#     u'damage_reflected_per_second': 0.3111111111111111,
#     'damage_reflected_to_output_ratio': 0.024800708591674048,
#     u'deaths': 4,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     'dragonblade_kills_per_life': 0.0,
#     'dragonblade_kills_per_second': 0.0,
#     'dragonblade_kills_to_dragonblades_ratio': 0.0,
#     'dragonblade_kills_to_eliminations_ratio': 0.0,
#     'dragonblades_per_life': 0.0,
#     'dragonblades_per_second': 0.0,
#     u'eliminations_per_life': 1.6,
#     u'eliminations_per_second': 0.044444444444444446,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.75,
#     u'final_blows_per_life': 1.2,
#     u'final_blows_per_second': 0.03333333333333333,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     u'games_won': 0,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'medals_-_bronze_per_game': 0.0,
#     'medals_-_gold_per_game': 0.0,
#     u'medals_-_silver_per_game': 0.0,
#     u'medals_per_game': 0.0,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.125,
#     u'objective_kills_per_life': 0.2,
#     u'objective_kills_per_second': 0.005555555555555556,
#     u'objective_time_seconds_per_life': 0.2,
#     u'objective_time_seconds_per_second': 0.005555555555555556,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     'quick_melee_accuracy': 0,
#     'recon_assists_per_life': 0.0,
#     'recon_assists_per_second': 0.0,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.375,
#     u'solo_kills_per_life': 0.6,
#     u'solo_kills_per_second': 0.016666666666666666,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 180,
#     u'time_spent_on_fire_seconds_per_life': 2.8,
#     u'time_spent_on_fire_seconds_per_second': 0.07777777777777778,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'weapon_accuracy': 0.34,
#     u'win_percentage': 0.98},
#    {u'all_damage_done': 2258,
#     'barrier_damage_done': 0,
#     'cards': 0,
#     u'critical_hit_accuracy': 0.05,
#     u'critical_hits': 4,
#     u'damage_reflected': 56,
#     u'deaths': 4,
#     'defensive_assists': 0,
#     'dragonblade_kills': 0,
#     'dragonblades': 0,
#     u'eliminations': 8,
#     'environmental_kills': 0,
#     u'final_blows': 6,
#     'games_lost': 0,
#     u'games_played': 0,
#     'games_tied': 0,
#     u'games_won': 0,
#     'healing_done': 0,
#     'hero_damage_done': 0,
#     u'medals': 0,
#     u'medals_-_bronze': 0,
#     'medals_-_gold': 0,
#     u'medals_-_silver': 0,
#     'melee_final_blows': 0,
#     'multikills': 0,
#     u'objective_kills': 1,
#     u'objective_time_seconds': 1,
#     'offensive_assists': 0,
#     'quick_melee_accuracy': 0,
#     'recon_assists': 0,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 3,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 180,
#     u'time_spent_on_fire_seconds': 14,
#     'turrets_destroyed': 0,
#     u'weapon_accuracy': 0.34,
#     u'win_percentage': 0.98}),
#   (u'Microcity#1653',
#    {'SR': 2830,
#     u'all_damage_done_per_life': 1340.408163265306,
#     u'all_damage_done_per_second': 18.244444444444444,
#     'average_life': 73.46938775510205,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     u'cards_per_game': 0.125,
#     u'critical_hit_accuracy': 0.07,
#     u'critical_hits_per_life': 1.9081632653061225,
#     u'critical_hits_per_second': 0.025972222222222223,
#     u'damage_reflected_per_life': 255.66326530612244,
#     u'damage_reflected_per_second': 3.479861111111111,
#     'damage_reflected_to_output_ratio': 0.19073538367844092,
#     u'deaths': 97,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'dragonblade_kills_per_life': 0.5204081632653061,
#     u'dragonblade_kills_per_second': 0.007083333333333333,
#     'dragonblade_kills_to_dragonblades_ratio': 1.0408163265306123,
#     'dragonblade_kills_to_eliminations_ratio': 0.19540229885057472,
#     u'dragonblades_per_life': 0.5,
#     u'dragonblades_per_second': 0.006805555555555555,
#     u'eliminations_per_life': 2.663265306122449,
#     u'eliminations_per_second': 0.03625,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.4789272030651341,
#     u'final_blows_per_life': 1.2755102040816326,
#     u'final_blows_per_second': 0.017361111111111112,
#     'games_lost': 5,
#     u'games_played': 8,
#     u'games_tied': 0,
#     u'games_won': 3,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'medals_-_bronze_per_game': 1.0,
#     u'medals_-_gold_per_game': 1.25,
#     u'medals_-_silver_per_game': 0.75,
#     u'medals_per_game': 3.0,
#     u'melee_final_blows_per_life': 0.07142857142857142,
#     u'melee_final_blows_per_second': 0.0009722222222222222,
#     u'multikills_per_life': 0.01020408163265306,
#     u'multikills_per_second': 0.0001388888888888889,
#     'objective_kills_per_elimination': 0.41379310344827586,
#     u'objective_kills_per_life': 1.1020408163265305,
#     u'objective_kills_per_second': 0.015,
#     u'objective_time_seconds_per_life': 8.23469387755102,
#     u'objective_time_seconds_per_second': 0.11208333333333333,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     'quick_melee_accuracy': 0,
#     'recon_assists_per_life': 0.0,
#     'recon_assists_per_second': 0.0,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.09578544061302682,
#     u'solo_kills_per_life': 0.25510204081632654,
#     u'solo_kills_per_second': 0.003472222222222222,
#     u'teleporter_pads_destroyed_per_life': 0.01020408163265306,
#     u'teleporter_pads_destroyed_per_second': 0.0001388888888888889,
#     u'time_played_seconds': 7200,
#     u'time_spent_on_fire_seconds_per_life': 5.704081632653061,
#     u'time_spent_on_fire_seconds_per_second': 0.07763888888888888,
#     u'turrets_destroyed_per_life': 0.15306122448979592,
#     u'turrets_destroyed_per_second': 0.0020833333333333333,
#     u'weapon_accuracy': 0.37,
#     u'win_percentage': 0.34},
#    {u'all_damage_done': 131360,
#     'barrier_damage_done': 0,
#     u'cards': 1,
#     u'critical_hit_accuracy': 0.07,
#     u'critical_hits': 187,
#     u'damage_reflected': 25055,
#     u'deaths': 97,
#     'defensive_assists': 0,
#     u'dragonblade_kills': 51,
#     u'dragonblades': 49,
#     u'eliminations': 261,
#     'environmental_kills': 0,
#     u'final_blows': 125,
#     'games_lost': 5,
#     u'games_played': 8,
#     u'games_tied': 0,
#     u'games_won': 3,
#     'healing_done': 0,
#     'hero_damage_done': 0,
#     u'medals': 24,
#     u'medals_-_bronze': 8,
#     u'medals_-_gold': 10,
#     u'medals_-_silver': 6,
#     u'melee_final_blows': 7,
#     u'multikills': 1,
#     u'objective_kills': 108,
#     u'objective_time_seconds': 807,
#     'offensive_assists': 0,
#     'quick_melee_accuracy': 0,
#     'recon_assists': 0,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 25,
#     u'teleporter_pads_destroyed': 1,
#     u'time_played_seconds': 7200,
#     u'time_spent_on_fire_seconds': 559,
#     u'turrets_destroyed': 15,
#     u'weapon_accuracy': 0.37,
#     u'win_percentage': 0.34}),
#   (u'Mushmak#1423',
#    {'SR': 3982,
#     u'all_damage_done_per_life': 656.5,
#     u'all_damage_done_per_second': 14.308333333333334,
#     'average_life': 45.88235294117647,
#     u'barrier_damage_done_per_life': 172.47058823529412,
#     u'barrier_damage_done_per_second': 3.758974358974359,
#     'cards_per_game': 0.0,
#     u'critical_hit_accuracy': 0.07,
#     u'critical_hits_per_life': 0.9117647058823529,
#     u'critical_hits_per_second': 0.01987179487179487,
#     u'damage_reflected_per_life': 123.61764705882354,
#     u'damage_reflected_per_second': 2.6942307692307694,
#     'damage_reflected_to_output_ratio': 0.1882980153218942,
#     u'deaths': 33,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'dragonblade_kills_per_life': 0.14705882352941177,
#     u'dragonblade_kills_per_second': 0.003205128205128205,
#     'dragonblade_kills_to_dragonblades_ratio': 0.625,
#     'dragonblade_kills_to_eliminations_ratio': 0.1282051282051282,
#     u'dragonblades_per_life': 0.23529411764705882,
#     u'dragonblades_per_second': 0.005128205128205128,
#     u'eliminations_per_life': 1.1470588235294117,
#     u'eliminations_per_second': 0.025,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.46153846153846156,
#     u'final_blows_per_life': 0.5294117647058824,
#     u'final_blows_per_second': 0.011538461538461539,
#     'games_lost': 3,
#     u'games_played': 3,
#     'games_tied': 0,
#     u'games_won': 0,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     u'hero_damage_done_per_life': 465.0882352941176,
#     u'hero_damage_done_per_second': 10.136538461538462,
#     'hero_to_barrier_damage_ratio': 2.69662346521146,
#     u'medals_-_bronze_per_game': 1.3333333333333333,
#     u'medals_-_gold_per_game': 0.3333333333333333,
#     u'medals_-_silver_per_game': 0.3333333333333333,
#     u'medals_per_game': 2.0,
#     u'melee_final_blows_per_life': 0.08823529411764706,
#     u'melee_final_blows_per_second': 0.0019230769230769232,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.41025641025641024,
#     u'objective_kills_per_life': 0.47058823529411764,
#     u'objective_kills_per_second': 0.010256410256410256,
#     u'objective_time_seconds_per_life': 3.823529411764706,
#     u'objective_time_seconds_per_second': 0.08333333333333333,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     u'quick_melee_accuracy': 0,
#     'recon_assists_per_life': 0.0,
#     'recon_assists_per_second': 0.0,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
# ...
#     u'deaths': 118,
#     'defensive_assists_per_life': 0.0,
#     'defensive_assists_per_second': 0.0,
#     u'eliminations_per_life': 2.9831932773109244,
#     u'eliminations_per_second': 0.049305555555555554,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.2535211267605634,
#     u'final_blows_per_life': 0.7563025210084033,
#     u'final_blows_per_second': 0.0125,
#     'games_lost': 6,
#     u'games_played': 12,
#     'games_tied': 0,
#     u'games_won': 7,
#     u'graviton_surge_kills_per_life': 0.4957983193277311,
#     u'graviton_surge_kills_per_second': 0.008194444444444445,
#     'graviton_surge_kills_to_eliminations_ratio': 0.16619718309859155,
#     'healing_done_per_life': 0.0,
#     'healing_done_per_second': 0.0,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'high_energy_kills_per_life': 1.1008403361344539,
#     u'high_energy_kills_per_second': 0.018194444444444444,
#     'high_energy_kills_to_eliminations_ratio': 0.36901408450704226,
#     u'medals_-_bronze_per_game': 1.25,
#     u'medals_-_gold_per_game': 1.0,
#     u'medals_-_silver_per_game': 1.0833333333333333,
#     u'medals_per_game': 3.3333333333333335,
#     u'melee_final_blows_per_life': 0.01680672268907563,
#     u'melee_final_blows_per_second': 0.0002777777777777778,
#     u'multikills_per_life': 0.07563025210084033,
#     u'multikills_per_second': 0.00125,
#     'objective_kills_per_elimination': 0.523943661971831,
#     u'objective_kills_per_life': 1.5630252100840336,
#     u'objective_kills_per_second': 0.025833333333333333,
#     u'objective_time_seconds_per_life': 12.731092436974789,
#     u'objective_time_seconds_per_second': 0.21041666666666667,
#     'offensive_assists_per_life': 0.0,
#     'offensive_assists_per_second': 0.0,
#     'primary_fire_accuracy': 0,
#     u'projected_barriers_applied_per_life': 4.260504201680672,
#     u'projected_barriers_applied_per_second': 0.07041666666666667,
#     'quick_melee_accuracy': 0,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.014084507042253521,
#     u'solo_kills_per_life': 0.04201680672268908,
#     u'solo_kills_per_second': 0.0006944444444444445,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 7200,
#     u'time_spent_on_fire_seconds_per_life': 4.663865546218488,
#     u'time_spent_on_fire_seconds_per_second': 0.07708333333333334,
#     u'turrets_destroyed_per_life': 0.06722689075630252,
#     u'turrets_destroyed_per_second': 0.0011111111111111111,
#     u'weapon_accuracy': 0.56,
#     u'win_percentage': 0.52},
#    {u'all_damage_done': 166607,
#     'barrier_damage_done': 0,
#     u'cards': 2,
#     'critical_hit_accuracy': 0,
#     'critical_hits': 0,
#     u'damage_blocked': 73799,
#     u'deaths': 118,
#     'defensive_assists': 0,
#     u'eliminations': 355,
#     'environmental_kills': 0,
#     u'final_blows': 90,
#     'games_lost': 6,
#     u'games_played': 12,
#     'games_tied': 0,
#     u'games_won': 7,
#     u'graviton_surge_kills': 59,
#     'healing_done': 0,
#     'hero_damage_done': 0,
#     u'high_energy_kills': 131,
#     u'medals': 40,
#     u'medals_-_bronze': 15,
#     u'medals_-_gold': 12,
#     u'medals_-_silver': 13,
#     u'melee_final_blows': 2,
#     u'multikills': 9,
#     u'objective_kills': 186,
#     u'objective_time_seconds': 1515,
#     'offensive_assists': 0,
#     'primary_fire_accuracy': 0,
#     u'projected_barriers_applied': 507,
#     'quick_melee_accuracy': 0,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 5,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 7200,
#     u'time_spent_on_fire_seconds': 555,
#     u'turrets_destroyed': 8,
#     u'weapon_accuracy': 0.56,
#     u'win_percentage': 0.52})],
#  'zenyatta': [(u'Microcity#1653',
#    {'SR': 2830,
#     u'all_damage_done_per_life': 992.875,
#     u'all_damage_done_per_second': 13.238333333333333,
#     'average_life': 75.0,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     u'cards_per_game': 1.0,
#     u'critical_hit_accuracy': 0.08,
#     u'critical_hits_per_life': 1.625,
#     u'critical_hits_per_second': 0.021666666666666667,
#     u'deaths': 7,
#     u'defensive_assists_per_life': 3.5,
#     u'defensive_assists_per_second': 0.04666666666666667,
#     u'eliminations_per_life': 3.375,
#     u'eliminations_per_second': 0.045,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.3333333333333333,
#     u'final_blows_per_life': 1.125,
#     u'final_blows_per_second': 0.015,
#     'games_lost': 0,
#     u'games_played': 1,
#     'games_tied': 0,
#     u'games_won': 1,
#     u'healing_done_per_life': 629.5,
#     u'healing_done_per_second': 8.393333333333333,
#     'healing_to_damage_ratio': 0.6340173737882412,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'medals_-_bronze_per_game': 0.0,
#     'medals_-_gold_per_game': 0.0,
#     u'medals_-_silver_per_game': 2.0,
#     u'medals_per_game': 3.0,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.37037037037037035,
#     u'objective_kills_per_life': 1.25,
#     u'objective_kills_per_second': 0.016666666666666666,
#     u'objective_time_seconds_per_life': 3.0,
#     u'objective_time_seconds_per_second': 0.04,
#     u'offensive_assists_per_life': 2.375,
#     u'offensive_assists_per_second': 0.03166666666666667,
#     'quick_melee_accuracy': 0,
#     u'self_healing_per_life': 15.75,
#     u'self_healing_per_second': 0.21,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.0,
#     'solo_kills_per_life': 0.0,
#     'solo_kills_per_second': 0.0,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 600,
#     u'time_spent_on_fire_seconds_per_life': 5.25,
#     u'time_spent_on_fire_seconds_per_second': 0.07,
#     u'transcendence_healing_-_best': 776,
#     u'transcendence_healing_per_life': 100.625,
#     u'transcendence_healing_per_second': 1.3416666666666666,
#     'transcendence_healing_to_healing_done_ratio': 0.15984908657664815,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'weapon_accuracy': 0.33,
#     u'win_percentage': 0.95},
#    {u'all_damage_done': 7943,
#     'barrier_damage_done': 0,
#     u'cards': 1,
#     u'critical_hit_accuracy': 0.08,
#     u'critical_hits': 13,
#     u'deaths': 7,
#     u'defensive_assists': 28,
#     u'eliminations': 27,
#     'environmental_kills': 0,
#     u'final_blows': 9,
#     'games_lost': 0,
#     u'games_played': 1,
#     'games_tied': 0,
#     u'games_won': 1,
#     u'healing_done': 5036,
#     'hero_damage_done': 0,
#     u'medals': 3,
#     u'medals_-_bronze': 0,
#     'medals_-_gold': 0,
#     u'medals_-_silver': 2,
#     'melee_final_blows': 0,
#     'multikills': 0,
#     u'objective_kills': 10,
#     u'objective_time_seconds': 24,
#     u'offensive_assists': 19,
#     'quick_melee_accuracy': 0,
#     u'self_healing': 126,
#     'shield_generators_destroyed': 0,
#     'solo_kills': 0,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 600,
#     u'time_spent_on_fire_seconds': 42,
#     u'transcendence_healing': 805,
#     u'transcendence_healing_-_best': 776,
#     'turrets_destroyed': 0,
#     u'weapon_accuracy': 0.33,
#     u'win_percentage': 0.95}),
#   (u'Mushmak#1423',
#    {'SR': 3982,
#     u'all_damage_done_per_life': 994.8886075949367,
#     u'all_damage_done_per_second': 15.594484126984128,
#     'average_life': 63.79746835443038,
#     u'barrier_damage_done_per_life': 369.1518987341772,
#     u'barrier_damage_done_per_second': 5.786309523809524,
#     u'cards_per_game': 0.4864864864864865,
#     u'critical_hit_accuracy': 0.08,
#     u'critical_hits_per_life': 1.0759493670886076,
#     u'critical_hits_per_second': 0.016865079365079364,
#     u'deaths': 394,
#     u'defensive_assists_per_life': 2.40253164556962,
#     u'defensive_assists_per_second': 0.037658730158730155,
#     u'eliminations_per_life': 1.8556962025316455,
#     u'eliminations_per_second': 0.02908730158730159,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.30286493860845837,
#     u'final_blows_per_life': 0.5620253164556962,
#     u'final_blows_per_second': 0.008809523809523809,
#     'games_lost': 17,
#     u'games_played': 37,
#     u'games_tied': 1,
#     u'games_won': 20,
#     u'healing_done_per_life': 694.7012658227848,
#     u'healing_done_per_second': 10.889166666666666,
#     'healing_to_damage_ratio': 0.6982703998412138,
#     u'hero_damage_done_per_life': 618.9518987341772,
#     u'hero_damage_done_per_second': 9.701825396825397,
#     'hero_to_barrier_damage_ratio': 1.6766862119809347,
#     u'medals_-_bronze_per_game': 0.5135135135135135,
#     u'medals_-_gold_per_game': 0.2972972972972973,
#     u'medals_-_silver_per_game': 1.4594594594594594,
#     u'medals_per_game': 2.27027027027027,
#     u'melee_final_blows_per_life': 0.017721518987341773,
#     u'melee_final_blows_per_second': 0.0002777777777777778,
#     u'multikills_per_life': 0.007594936708860759,
#     u'multikills_per_second': 0.00011904761904761905,
#     'objective_kills_per_elimination': 0.44747612551159616,
#     u'objective_kills_per_life': 0.830379746835443,
#     u'objective_kills_per_second': 0.013015873015873015,
#     u'objective_time_seconds_per_life': 6.516455696202532,
#     u'objective_time_seconds_per_second': 0.10214285714285715,
#     u'offensive_assists_per_life': 2.1848101265822786,
#     u'offensive_assists_per_second': 0.034246031746031746,
#     u'quick_melee_accuracy': 0,
#     u'self_healing_per_life': 16.10632911392405,
#     u'self_healing_per_second': 0.25246031746031744,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.03547066848567531,
#     u'solo_kills_per_life': 0.06582278481012659,
#     u'solo_kills_per_second': 0.0010317460317460319,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 25200,
#     u'time_spent_on_fire_seconds_per_life': 5.582278481012659,
#     u'time_spent_on_fire_seconds_per_second': 0.0875,
#     u'transcendence_healing_-_best': 1949,
#     u'transcendence_healing_per_life': 246.36708860759492,
#     u'transcendence_healing_per_second': 3.861706349206349,
#     'transcendence_healing_to_healing_done_ratio': 0.3546374545838845,
#     u'turrets_destroyed_per_life': 0.012658227848101266,
#     u'turrets_destroyed_per_second': 0.0001984126984126984,
#     u'weapon_accuracy': 0.24,
#     u'win_percentage': 0.54},
#    {u'all_damage_done': 392981,
#     u'barrier_damage_done': 145815,
#     u'cards': 18,
#     u'critical_hit_accuracy': 0.08,
#     u'critical_hits': 425,
#     u'deaths': 394,
#     u'defensive_assists': 949,
#     u'eliminations': 733,
#     'environmental_kills': 0,
#     u'final_blows': 222,
#     'games_lost': 17,
#     u'games_played': 37,
#     u'games_tied': 1,
#     u'games_won': 20,
#     u'healing_done': 274407,
#     u'hero_damage_done': 244486,
#     u'medals': 84,
#     u'medals_-_bronze': 19,
#     u'medals_-_gold': 11,
#     u'medals_-_silver': 54,
#     u'melee_final_blows': 7,
#     u'multikills': 3,
#     u'objective_kills': 328,
#     u'objective_time_seconds': 2574,
#     u'offensive_assists': 863,
#     u'quick_melee_accuracy': 0,
#     u'self_healing': 6362,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 26,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 25200,
#     u'time_spent_on_fire_seconds': 2205,
#     u'transcendence_healing': 97315,
#     u'transcendence_healing_-_best': 1949,
#     u'turrets_destroyed': 5,
#     u'weapon_accuracy': 0.24,
#     u'win_percentage': 0.54}),
#   (u'FINALBOSS#12814',
#    {'SR': 2668,
#     u'all_damage_done_per_life': 1321.9722222222222,
#     u'all_damage_done_per_second': 15.552614379084968,
#     'average_life': 85.0,
#     'barrier_damage_done_per_life': 0.0,
#     'barrier_damage_done_per_second': 0.0,
#     u'cards_per_game': 0.6666666666666666,
#     u'critical_hit_accuracy': 0.04,
#     u'critical_hits_per_life': 1.1944444444444444,
#     u'critical_hits_per_second': 0.014052287581699347,
#     u'deaths': 35,
#     u'defensive_assists_per_life': 2.5277777777777777,
#     u'defensive_assists_per_second': 0.029738562091503266,
#     u'eliminations_per_life': 1.9166666666666667,
#     u'eliminations_per_second': 0.022549019607843137,
#     'environmental_kills_per_life': 0.0,
#     'environmental_kills_per_second': 0.0,
#     'final_blows_per_elimination': 0.3333333333333333,
#     u'final_blows_per_life': 0.6388888888888888,
#     u'final_blows_per_second': 0.007516339869281046,
#     'games_lost': 3,
#     u'games_played': 3,
#     'games_tied': 0,
#     u'games_won': 0,
#     u'healing_done_per_life': 821.6111111111111,
#     u'healing_done_per_second': 9.666013071895424,
#     'healing_to_damage_ratio': 0.621504065894812,
#     'hero_damage_done_per_life': 0.0,
#     'hero_damage_done_per_second': 0.0,
#     'hero_to_barrier_damage_ratio': 0.0,
#     u'medals_-_bronze_per_game': 1.6666666666666667,
#     u'medals_-_gold_per_game': 0.3333333333333333,
#     u'medals_-_silver_per_game': 1.0,
#     u'medals_per_game': 3.0,
#     'melee_final_blows_per_life': 0.0,
#     'melee_final_blows_per_second': 0.0,
#     'multikills_per_life': 0.0,
#     'multikills_per_second': 0.0,
#     'objective_kills_per_elimination': 0.4927536231884058,
#     u'objective_kills_per_life': 0.9444444444444444,
#     u'objective_kills_per_second': 0.011111111111111112,
#     u'objective_time_seconds_per_life': 11.13888888888889,
#     u'objective_time_seconds_per_second': 0.13104575163398693,
#     u'offensive_assists_per_life': 1.8333333333333333,
#     u'offensive_assists_per_second': 0.021568627450980392,
#     'quick_melee_accuracy': 0,
#     u'self_healing_per_life': 18.11111111111111,
#     u'self_healing_per_second': 0.2130718954248366,
#     'shield_generators_destroyed_per_life': 0.0,
#     'shield_generators_destroyed_per_second': 0.0,
#     'solo_kills_per_elimination': 0.028985507246376812,
#     u'solo_kills_per_life': 0.05555555555555555,
#     u'solo_kills_per_second': 0.00065359477124183,
#     'teleporter_pads_destroyed_per_life': 0.0,
#     'teleporter_pads_destroyed_per_second': 0.0,
#     u'time_played_seconds': 3060,
#     u'time_spent_on_fire_seconds_per_life': 3.611111111111111,
#     u'time_spent_on_fire_seconds_per_second': 0.042483660130718956,
#     u'transcendence_healing_-_best': 1824,
#     u'transcendence_healing_per_life': 240.77777777777777,
#     u'transcendence_healing_per_second': 2.8326797385620917,
#     'transcendence_healing_to_healing_done_ratio': 0.2930556494692001,
#     'turrets_destroyed_per_life': 0.0,
#     'turrets_destroyed_per_second': 0.0,
#     u'weapon_accuracy': 0.36,
#     u'win_percentage': 0.05},
#    {u'all_damage_done': 47591,
#     'barrier_damage_done': 0,
#     u'cards': 2,
#     u'critical_hit_accuracy': 0.04,
#     u'critical_hits': 43,
#     u'deaths': 35,
#     u'defensive_assists': 91,
#     u'eliminations': 69,
#     'environmental_kills': 0,
#     u'final_blows': 23,
#     'games_lost': 3,
#     u'games_played': 3,
#     'games_tied': 0,
#     u'games_won': 0,
#     u'healing_done': 29578,
#     'hero_damage_done': 0,
#     u'medals': 9,
#     u'medals_-_bronze': 5,
#     u'medals_-_gold': 1,
#     u'medals_-_silver': 3,
#     'melee_final_blows': 0,
#     'multikills': 0,
#     u'objective_kills': 34,
#     u'objective_time_seconds': 401,
#     u'offensive_assists': 66,
#     'quick_melee_accuracy': 0,
#     u'self_healing': 652,
#     'shield_generators_destroyed': 0,
#     u'solo_kills': 2,
#     'teleporter_pads_destroyed': 0,
#     u'time_played_seconds': 3060,
#     u'time_spent_on_fire_seconds': 130,
#     u'transcendence_healing': 8668,
#     u'transcendence_healing_-_best': 1824,
#     'turrets_destroyed': 0,
#     u'weapon_accuracy': 0.36,
#     u'win_percentage': 0.05})]}
